# %%
# DATA SET IMPORTING AND PROCESSSING
from PIL import Image, ImageDraw, ImageOps
import matplotlib.pyplot as plt
import ast
import os
import numpy as np
import pandas as pd 
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
import torchvision.datasets as datasets

# %%
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print(files)
# Out:
# ['DEEPLEARNIN▒╨зў', 'mobile_lanebatch32withresizecrop.pt', 'mobile_lane_noresizecrop.pt', '.ipynb_checkpoints', 'mobile_lane_b16withreszeicrop.pt', 'Finals_Classifier.ipynb', 'mobile_lane64.pt', 'dense_lane.pt', 'Trail_dataset', 'mobile_lane_unfreezed.pt']

# %%
# storing gpu availability on boolean var
is_cuda = torch.cuda.is_available()

# checking for GPU
if is_cuda:
    device = torch.device("cuda")
    os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# GPU is available

# %%
BATCH_SIZE = 32

transform=transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(256),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225] )
    ])
train_data = datasets.ImageFolder('Trail_dataset/train_data/', transform=transform)
test_data = datasets.ImageFolder('Trail_dataset/test_data/', transform=transform)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=True)

# %%
print(next(iter(train_loader)))
# Out:
# [tensor([[[[ 0.1597,  0.1939,  0.1768,  ...,  0.1083,  0.1254,  0.1254],
#           [ 0.1597,  0.1597,  0.1426,  ...,  0.0912,  0.1083,  0.1083],
#           [ 0.1083,  0.0912,  0.1083,  ...,  0.1083,  0.1083,  0.1083],
#           ...,
#           [-0.0458, -0.1143, -0.1657,  ..., -0.0972, -0.0972, -0.0972],
#           [-0.0629, -0.1486, -0.2171,  ..., -0.0972, -0.0972, -0.1143],
#           [-0.0801, -0.1486, -0.2171,  ..., -0.1143, -0.0972, -0.1143]],
#
#          [[ 0.2927,  0.3102,  0.2927,  ...,  0.2227,  0.2402,  0.2402],
#           [ 0.2927,  0.2927,  0.2752,  ...,  0.2052,  0.2227,  0.2227],
#           [ 0.2402,  0.2227,  0.2402,  ...,  0.2227,  0.2227,  0.2227],
#           ...,
#           [ 0.0301, -0.0224, -0.0574,  ...,  0.0476,  0.0476,  0.0476],
#           [ 0.0126, -0.0749, -0.1275,  ...,  0.0301,  0.0301,  0.0301],
#           [-0.0049, -0.0749, -0.1450,  ...,  0.0126,  0.0301,  0.0301]],
#
#          [[ 0.5485,  0.5485,  0.5311,  ...,  0.5311,  0.5485,  0.5485],
#           [ 0.5485,  0.5485,  0.5136,  ...,  0.5136,  0.5311,  0.5485],
#           [ 0.4962,  0.4788,  0.4962,  ...,  0.5311,  0.5311,  0.5485],
#           ...,
#           [ 0.1302,  0.0779,  0.0256,  ...,  0.1825,  0.1825,  0.1825],
#           [ 0.1128,  0.0256, -0.0267,  ...,  0.1999,  0.1999,  0.1825],
#           [ 0.0953,  0.0256, -0.0441,  ...,  0.1999,  0.2173,  0.1825]]],
#
#
#         [[[ 1.1529,  1.1529,  1.1358,  ..., -0.4568, -0.4568, -0.4739],
#           [ 1.1700,  1.1529,  1.1358,  ..., -0.4397, -0.4739, -0.4911],
#           [ 1.1700,  1.1700,  1.1358,  ..., -0.4054, -0.4568, -0.4739],
#           ...,
#           [-0.0287, -0.0458, -0.0458,  ..., -0.3712, -0.3712, -0.3883],
#           [-0.0629, -0.0801, -0.0801,  ..., -0.3712, -0.3712, -0.4054],
#           [-0.0972, -0.1143, -0.0972,  ..., -0.3712, -0.3712, -0.3883]],
#
#          [[ 0.8354,  0.8529,  0.8354,  ..., -0.3901, -0.3725, -0.3550],
#           [ 0.8880,  0.8880,  0.8529,  ..., -0.3725, -0.3725, -0.3901],
#           [ 0.8880,  0.8880,  0.8704,  ..., -0.3025, -0.3375, -0.3725],
#           ...,
#           [ 0.1176,  0.1001,  0.1001,  ..., -0.2150, -0.2325, -0.2500],
#           [ 0.0826,  0.0651,  0.0651,  ..., -0.2150, -0.2500, -0.2675],
#           [ 0.0476,  0.0301,  0.0476,  ..., -0.2325, -0.2500, -0.2500]],
#
#          [[-0.8458, -0.9156, -1.0201,  ..., -0.2010, -0.1487, -0.1487],
#           [-0.9504, -1.0027, -1.0724,  ..., -0.2010, -0.1835, -0.1835],
#           [-0.9678, -0.9678, -1.0027,  ..., -0.1487, -0.1661, -0.1835],
#           ...,
#           [ 0.2348,  0.2348,  0.2173,  ..., -0.1138, -0.1138, -0.1312],
#           [ 0.1999,  0.1825,  0.1825,  ..., -0.0964, -0.1312, -0.1487],
#           [ 0.1651,  0.1476,  0.1651,  ..., -0.1138, -0.1312, -0.1312]]],
#
#
#         [[[-0.2684, -0.2856, -0.2856,  ..., -0.1999, -0.1828, -0.1999],
#           [-0.3198, -0.3027, -0.3027,  ..., -0.1999, -0.1999, -0.2171],
#           [-0.3712, -0.3541, -0.3712,  ..., -0.1999, -0.1999, -0.2342],
#           ...,
#           [ 0.1597,  0.1768,  0.2111,  ..., -0.1486, -0.1657, -0.1314],
#           [ 0.2111,  0.1768,  0.1597,  ..., -0.1657, -0.1657, -0.1143],
#           [ 0.3309,  0.2796,  0.1768,  ..., -0.1657, -0.1657, -0.1143]],
#
#          [[-0.2150, -0.2150, -0.2500,  ..., -0.1275, -0.1450, -0.1275],
#           [-0.2150, -0.2150, -0.2325,  ..., -0.1275, -0.1450, -0.1450],
#           [-0.2325, -0.2150, -0.2500,  ..., -0.1099, -0.1275, -0.1275],
#           ...,
#           [ 0.2227,  0.2402,  0.2752,  ..., -0.0049, -0.0224, -0.0224],
#           [ 0.2927,  0.2577,  0.2227,  ..., -0.0224, -0.0224, -0.0224],
#           [ 0.4153,  0.3627,  0.2577,  ..., -0.0224, -0.0224, -0.0399]],
#
#          [[-0.0615, -0.0790, -0.0790,  ..., -0.0267, -0.0267,  0.0082],
#           [-0.0615, -0.0441, -0.0790,  ...,  0.0082, -0.0267, -0.0092],
#           [-0.0964, -0.0790, -0.0790,  ...,  0.0256,  0.0082,  0.0082],
#           ...,
#           [ 0.3045,  0.3219,  0.3393,  ...,  0.1128,  0.0953,  0.0779],
#           [ 0.3568,  0.3219,  0.2871,  ...,  0.0953,  0.0953,  0.0953],
#           [ 0.4788,  0.4265,  0.3219,  ...,  0.0953,  0.0953,  0.0953]]],
#
#
#         ...,
#
#
#         [[[-0.2856, -0.3198, -0.3027,  ..., -0.1314, -0.1314, -0.0972],
#           [-0.2856, -0.3198, -0.3198,  ..., -0.1657, -0.1486, -0.1314],
#           [-0.3027, -0.3369, -0.3198,  ..., -0.1828, -0.1657, -0.1657],
#           ...,
#           [ 0.0227, -0.0116, -0.0116,  ..., -0.0801, -0.0287, -0.0116],
#           [ 0.0227,  0.0056,  0.0056,  ..., -0.0801, -0.0287, -0.0116],
#           [ 0.0227,  0.0056,  0.0056,  ..., -0.0629, -0.0458, -0.0116]],
#
#          [[-0.1975, -0.2325, -0.1800,  ...,  0.0126, -0.0049,  0.0301],
#           [-0.1975, -0.2150, -0.1975,  ..., -0.0399, -0.0224, -0.0049],
#           [-0.1975, -0.2150, -0.1975,  ..., -0.0574, -0.0399, -0.0399],
#           ...,
#           [ 0.1527,  0.1176,  0.1176,  ...,  0.0651,  0.1176,  0.1352],
#           [ 0.1702,  0.1352,  0.1352,  ...,  0.0651,  0.1176,  0.1352],
#           [ 0.1702,  0.1527,  0.1527,  ...,  0.0826,  0.1001,  0.1352]],
#
#          [[ 0.0431,  0.0082,  0.0431,  ...,  0.1651,  0.1825,  0.2173],
#           [ 0.0431,  0.0082,  0.0256,  ...,  0.1476,  0.1825,  0.1825],
#           [ 0.0605,  0.0431,  0.0431,  ...,  0.1651,  0.1999,  0.1825],
#           ...,
#           [ 0.3916,  0.3393,  0.3393,  ...,  0.1825,  0.2522,  0.2696],
#           [ 0.4265,  0.3742,  0.3568,  ...,  0.1825,  0.2348,  0.2522],
#           [ 0.4265,  0.4091,  0.3568,  ...,  0.1999,  0.2173,  0.2522]]],
#
#
#         [[[ 0.0056, -0.0116,  0.0056,  ..., -0.0629, -0.1314, -0.0972],
#           [ 0.0056, -0.0116,  0.0056,  ..., -0.0629, -0.1314, -0.0972],
#           [ 0.0227,  0.0398,  0.0056,  ..., -0.0629, -0.1143, -0.0801],
#           ...,
#           [-0.3198, -0.3027, -0.3541,  ..., -0.3198, -0.3027, -0.1999],
#           [-0.3541, -0.3369, -0.3541,  ..., -0.3027, -0.3198, -0.2513],
#           [-0.3883, -0.3883, -0.3541,  ..., -0.2513, -0.3198, -0.2856]],
#
#          [[ 0.1001,  0.0826,  0.1001,  ...,  0.0301, -0.0224, -0.0049],
#           [ 0.1001,  0.0826,  0.1001,  ...,  0.0301, -0.0224, -0.0049],
#           [ 0.0826,  0.1001,  0.1001,  ...,  0.0301, -0.0224, -0.0224],
#           ...,
#           [-0.1975, -0.1800, -0.2325,  ..., -0.2500, -0.2500, -0.1450],
#           [-0.2325, -0.2150, -0.2150,  ..., -0.2325, -0.2675, -0.1975],
#           [-0.2500, -0.2325, -0.1975,  ..., -0.1975, -0.2675, -0.2500]],
#
#          [[ 0.3393,  0.3219,  0.3393,  ...,  0.2696,  0.1999,  0.2348],
#           [ 0.3393,  0.3219,  0.3393,  ...,  0.2696,  0.1999,  0.2348],
#           [ 0.3219,  0.3393,  0.3393,  ...,  0.2696,  0.2173,  0.2522],
#           ...,
#           [-0.0092,  0.0082, -0.0441,  ..., -0.1487, -0.1661, -0.0615],
#           [-0.0441, -0.0092, -0.0267,  ..., -0.1312, -0.2010, -0.0964],
#           [-0.0441, -0.0267,  0.0082,  ..., -0.0964, -0.2010, -0.1661]]],
#
#
#         [[[ 0.0569,  0.0569,  0.0569,  ..., -0.1314, -0.1828, -0.2342],
#           [ 0.0569,  0.0569,  0.0569,  ..., -0.1486, -0.1486, -0.1828],
#           [ 0.0741,  0.0569,  0.0569,  ..., -0.1143, -0.1143, -0.0801],
#           ...,
#           [ 0.0569,  0.0741,  0.0912,  ..., -0.7479, -0.2684, -0.1314],
#           [ 0.0741,  0.0741,  0.0741,  ..., -0.8849, -0.3198, -0.1657],
#           [ 0.0741,  0.0569,  0.0741,  ..., -1.0562, -0.3883, -0.1999]],
#
#          [[ 0.1001,  0.1001,  0.1001,  ..., -0.1450, -0.1450, -0.1450],
#           [ 0.1001,  0.1001,  0.1001,  ..., -0.1275, -0.1099, -0.1275],
#           [ 0.1352,  0.1001,  0.1001,  ..., -0.0574, -0.0399, -0.0399],
#           ...,
#           [ 0.2052,  0.2402,  0.2577,  ..., -0.3550, -0.0224,  0.0301],
#           [ 0.2227,  0.2227,  0.2227,  ..., -0.4776, -0.0399,  0.0126],
#           [ 0.2052,  0.1877,  0.2052,  ..., -0.6527, -0.0749,  0.0126]],
#
#          [[ 0.2522,  0.2522,  0.2522,  ...,  0.0256,  0.0082, -0.0441],
#           [ 0.2522,  0.2522,  0.2522,  ...,  0.0431,  0.0431, -0.0092],
#           [ 0.2696,  0.2522,  0.2522,  ...,  0.0779,  0.0953,  0.0953],
#           ...,
#           [ 0.4614,  0.4614,  0.4614,  ...,  0.1476,  0.1128,  0.0779],
#           [ 0.4439,  0.4265,  0.4265,  ...,  0.0779,  0.0953,  0.0431],
#           [ 0.4265,  0.4091,  0.3916,  ..., -0.0790,  0.0605,  0.0082]]]]), tensor([ 6, 11,  3,  4, 12,  6, 15, 17,  1, 11, 12, 14,  4, 10,  4,  7, 15, 16,
#          6, 17, 17,  3,  2, 13,  9, 17,  7,  2,  6, 13, 17, 17])]

# %%
import matplotlib.pyplot as plt

images,gt = next(iter(train_loader))

fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  npimg = images[i].numpy()
  npimg = (npimg - np.min(npimg))/np.ptp(npimg)
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.title("Ground Truth: {}".format(gt[i]))
  plt.xticks([])
  plt.yticks([])

# %%
# Load the model based on DenseNet-161
lane_net = torchvision.models.mobilenet_v2(pretrained=True)
# lane_net = torchvision.models.densenet121(pretrained=True)

# # freeze the layers
# for param in lane_net.parameters():
#    param.requires_grad = False

# Modify the last layer for mobil
num_ftrs = lane_net.classifier[1].in_features
lane_net.classifier[1] = nn.Linear(num_ftrs, 18)

# modify for dense
# num_ftrs = lane_net.classifier.in_features
# lane_net.classifier = nn.Linear(num_ftrs, 18)

# send to gpu
lane_net = lane_net.to(device=device)

# PATH = 'dense_lane.pt'
# lane_net.load_state_dict(torch.load(PATH))
# lane_net.eval()
# optimizer = optim.SGD(draw_net.parameters(),lr=0.001, momentum=0.9)
optimizer = optim.Adam(lane_net.parameters(),lr=0.001)
criterion = nn.CrossEntropyLoss()
EPOCHS = 100

# %%
def test_acc():
    predictions = []
    gts = []
    for batch_idx, (X_batch, y_batch) in enumerate(test_loader):
        var_X_batch = Variable(X_batch).float().to(device=device)
        var_y_batch = Variable(y_batch).to(device=device)

        output = lane_net(var_X_batch)
        predicted = torch.max(output.data, 1)[1] 

        predictions.append(predicted.cpu().detach().numpy()[0])
        gts.append(var_y_batch.cpu().detach().numpy()[0])
        total_train_accuracy = (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 
    return total_train_accuracy

# %%
learning_curve = []
training_acc = []
highest_test_acc = 0
for epoch in range(EPOCHS):
    correct = 0
    for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
        var_X_batch = Variable(X_batch)
        var_X_batch = var_X_batch.to(device=device)
        var_y_batch = Variable(y_batch).to(device=device)
        optimizer.zero_grad()
    
        output = lane_net(var_X_batch)
        predicted = torch.max(output.data, 1)[1] 
        loss = criterion(output,var_y_batch)
        loss.backward()
        optimizer.step()
        
        # accuracy
        correct = (predicted == var_y_batch).sum()
        total = len(predicted)

        accuracy = (predicted == var_y_batch).sum()/len(predicted)*100
    
        # learning curve
        cel = loss.item()
        learning_curve.append(cel)
            
        training_acc.append(accuracy.item())
        correct = 0 
        total = 0
        if batch_idx % 10 == 0: 
          accuracy = accuracy.item()
          currently_run = batch_idx*len(X_batch)
          data_total = len(train_loader.dataset)
          percent_of_data_run = 100.*batch_idx / len(train_loader)
          print('Epoch: {}[{}/{} ({:.0f}%)]\t Accuracy:{:.3f}%\t Error:{:.2f}'.format(
              epoch, currently_run, data_total, percent_of_data_run, accuracy, cel))
    epoch_test = test_acc()
    print("EPOCH:" + str(epoch) + ", test_accurac: " + str(epoch_test))
    if epoch_test > highest_test_acc:
        PATH = 'mobile_lane' + str(epoch) + 'epoch.pt'
        torch.save(lane_net.state_dict(), PATH)
# Out:
# Epoch: 0[0/5717 (0%)]	 Accuracy:3.125%	 Error:2.91
# Epoch: 0[320/5717 (6%)]	 Accuracy:50.000%	 Error:2.06
# Epoch: 0[640/5717 (11%)]	 Accuracy:43.750%	 Error:1.64
# Epoch: 0[960/5717 (17%)]	 Accuracy:31.250%	 Error:1.84
# Epoch: 0[1280/5717 (22%)]	 Accuracy:56.250%	 Error:1.16
# Epoch: 0[1600/5717 (28%)]	 Accuracy:56.250%	 Error:1.22
# Epoch: 0[1920/5717 (34%)]	 Accuracy:40.625%	 Error:1.56
# Epoch: 0[2240/5717 (39%)]	 Accuracy:50.000%	 Error:1.30
# Epoch: 0[2560/5717 (45%)]	 Accuracy:56.250%	 Error:1.33
# Epoch: 0[2880/5717 (50%)]	 Accuracy:46.875%	 Error:1.21
# Epoch: 0[3200/5717 (56%)]	 Accuracy:46.875%	 Error:1.22
# Epoch: 6[3840/5717 (67%)]	 Accuracy:84.375%	 Error:0.39
# Epoch: 6[4160/5717 (73%)]	 Accuracy:90.625%	 Error:0.36
# Epoch: 6[4480/5717 (78%)]	 Accuracy:71.875%	 Error:0.55
# Epoch: 6[4800/5717 (84%)]	 Accuracy:87.500%	 Error:0.58
# Epoch: 6[5120/5717 (89%)]	 Accuracy:93.750%	 Error:0.19
# Epoch: 6[5440/5717 (95%)]	 Accuracy:87.500%	 Error:0.36
# EPOCH:6, test_accurac: 74.07407407407408
# Epoch: 7[0/5717 (0%)]	 Accuracy:81.250%	 Error:0.51
# Epoch: 7[320/5717 (6%)]	 Accuracy:87.500%	 Error:0.45
# Epoch: 7[640/5717 (11%)]	 Accuracy:78.125%	 Error:0.61
# Epoch: 7[960/5717 (17%)]	 Accuracy:96.875%	 Error:0.15
# Epoch: 7[1280/5717 (22%)]	 Accuracy:96.875%	 Error:0.12
# Epoch: 7[1600/5717 (28%)]	 Accuracy:93.750%	 Error:0.26
# Epoch: 7[1920/5717 (34%)]	 Accuracy:90.625%	 Error:0.36
# Epoch: 7[2240/5717 (39%)]	 Accuracy:84.375%	 Error:0.40
# Epoch: 7[2560/5717 (45%)]	 Accuracy:90.625%	 Error:0.19
# Epoch: 7[2880/5717 (50%)]	 Accuracy:81.250%	 Error:0.49
# Epoch: 7[3200/5717 (56%)]	 Accuracy:90.625%	 Error:0.39
# Epoch: 7[3520/5717 (61%)]	 Accuracy:84.375%	 Error:0.48
# Epoch: 7[3840/5717 (67%)]	 Accuracy:90.625%	 Error:0.37
# Epoch: 7[4160/5717 (73%)]	 Accuracy:96.875%	 Error:0.13
# Epoch: 7[4480/5717 (78%)]	 Accuracy:90.625%	 Error:0.26
# Epoch: 7[4800/5717 (84%)]	 Accuracy:84.375%	 Error:0.46

# %%
predictions = []
gts = []
train_X = []
for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
    var_X_batch = Variable(X_batch).to(device=device)
    var_y_batch = Variable(y_batch).to(device=device)

    output = lane_net(var_X_batch)
    predicted = torch.max(output.data, 1)[1] 

    predictions.append(predicted.cpu().detach().numpy()[0])
    gts.append(var_y_batch.cpu().detach().numpy()[0])
    total_train_accuracy = (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 

print( "Training Accuracy: ", (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 )

# %%
predictions = []
gts = []
train_X = []
for batch_idx, (X_batch, y_batch) in enumerate(test_loader):
    var_X_batch = Variable(X_batch).float().to(device=device)
    var_y_batch = Variable(y_batch).to(device=device)

    output = lane_net(var_X_batch)
    predicted = torch.max(output.data, 1)[1] 

    predictions.append(predicted.cpu().detach().numpy()[0])
    gts.append(var_y_batch.cpu().detach().numpy()[0])
    total_train_accuracy = (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 

print( "Test Accuracy: ", (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 )

# %%
# PATH = 'dense_lane.pt'
# torch.save(lane_net.state_dict(), PATH)

# %%
print(total_train_accuracy)
