# %%
# DATA SET IMPORTING AND PROCESSSING
from PIL import Image, ImageDraw, ImageOps
import matplotlib.pyplot as plt
import ast
import os
import numpy as np
import pandas as pd 
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
import torchvision.datasets as datasets

# %%
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print(files)
# Out:
# ['12mobile', 'DEEPLEARNIN▒╨зў', 'mobilelaneweights', 'mobile_lanebatch32withresizecrop.pt', 'mobile_lane_noresizecrop.pt', '.ipynb_checkpoints', 'mobile_lane_b16withreszeicrop.pt', 'Finals_Classifier.ipynb', '99mobile', 'dense weights', 'Finals_Classifier-Copy1.ipynb', 'laneWithoutDropout', 'Trail_dataset']

# %%
# storing gpu availability on boolean var
is_cuda = torch.cuda.is_available()

# checking for GPU
if is_cuda:
    device = torch.device("cuda")
    os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# GPU is available

# %%
BATCH_SIZE = 8

transform=transforms.Compose([
    #transforms.Resize(256),
    #transforms.CenterCrop(256),
    transforms.ToTensor(),
    #transforms.Normalize(mean=[0.485, 0.456, 0.406],
    #                     std=[0.229, 0.224, 0.225] )
    ])
train_data = datasets.ImageFolder('Trail_dataset/train_data/', transform=transform)
test_data = datasets.ImageFolder('Trail_dataset/test_data/', transform=transform)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=True)

# %%
print(next(iter(train_loader)))
# Out:
# [tensor([[[[0.5569, 0.5490, 0.5490,  ..., 0.5255, 0.5373, 0.5333],
#           [0.5529, 0.5451, 0.5490,  ..., 0.5216, 0.5255, 0.5333],
#           [0.5529, 0.5451, 0.5529,  ..., 0.5216, 0.5216, 0.5333],
#           ...,
#           [0.4784, 0.4667, 0.4706,  ..., 0.5020, 0.4824, 0.4784],
#           [0.4784, 0.4667, 0.4745,  ..., 0.5059, 0.4863, 0.4784],
#           [0.4745, 0.4667, 0.4745,  ..., 0.5059, 0.4863, 0.4824]],
#
#          [[0.5725, 0.5647, 0.5725,  ..., 0.5216, 0.5333, 0.5294],
#           [0.5686, 0.5608, 0.5725,  ..., 0.5176, 0.5216, 0.5294],
#           [0.5686, 0.5608, 0.5686,  ..., 0.5176, 0.5176, 0.5294],
#           ...,
#           [0.4824, 0.4706, 0.4745,  ..., 0.4863, 0.4667, 0.4627],
#           [0.4824, 0.4706, 0.4784,  ..., 0.4902, 0.4706, 0.4627],
#           [0.4784, 0.4706, 0.4784,  ..., 0.4902, 0.4706, 0.4667]],
#
#          [[0.5765, 0.5686, 0.5725,  ..., 0.5412, 0.5529, 0.5490],
#           [0.5725, 0.5647, 0.5725,  ..., 0.5373, 0.5412, 0.5490],
#           [0.5725, 0.5647, 0.5725,  ..., 0.5373, 0.5373, 0.5490],
#           ...,
#           [0.4510, 0.4392, 0.4431,  ..., 0.4510, 0.4314, 0.4275],
#           [0.4510, 0.4392, 0.4471,  ..., 0.4549, 0.4353, 0.4275],
#           [0.4471, 0.4392, 0.4471,  ..., 0.4549, 0.4353, 0.4314]]],
#
#
#         [[[0.4588, 0.4627, 0.4627,  ..., 0.4784, 0.4824, 0.4706],
#           [0.4588, 0.4627, 0.4588,  ..., 0.4784, 0.4824, 0.4706],
#           [0.4549, 0.4549, 0.4510,  ..., 0.4784, 0.4824, 0.4745],
#           ...,
#           [0.4706, 0.4627, 0.4627,  ..., 0.5176, 0.5137, 0.5176],
#           [0.4667, 0.4627, 0.4588,  ..., 0.5176, 0.5176, 0.5176],
#           [0.4627, 0.4588, 0.4549,  ..., 0.5176, 0.5176, 0.5137]],
#
#          [[0.4706, 0.4745, 0.4745,  ..., 0.4745, 0.4784, 0.4667],
#           [0.4706, 0.4745, 0.4706,  ..., 0.4745, 0.4784, 0.4667],
#           [0.4667, 0.4667, 0.4627,  ..., 0.4745, 0.4784, 0.4706],
#           ...,
#           [0.5059, 0.4980, 0.4980,  ..., 0.5137, 0.5098, 0.5137],
#           [0.5020, 0.4980, 0.4941,  ..., 0.5137, 0.5137, 0.5137],
#           [0.4980, 0.4941, 0.4902,  ..., 0.5137, 0.5137, 0.5098]],
#
#          [[0.4431, 0.4471, 0.4471,  ..., 0.4667, 0.4706, 0.4588],
#           [0.4431, 0.4471, 0.4431,  ..., 0.4667, 0.4706, 0.4588],
#           [0.4392, 0.4392, 0.4353,  ..., 0.4667, 0.4706, 0.4627],
#           ...,
#           [0.4941, 0.4863, 0.4863,  ..., 0.5059, 0.5020, 0.5059],
#           [0.4902, 0.4863, 0.4824,  ..., 0.5059, 0.5059, 0.5059],
#           [0.4863, 0.4824, 0.4784,  ..., 0.4980, 0.5059, 0.5020]]],
#
#
#         [[[0.5490, 0.5333, 0.5294,  ..., 0.4510, 0.4392, 0.4118],
#           [0.5412, 0.5333, 0.5333,  ..., 0.4510, 0.4392, 0.4235],
#           [0.5294, 0.5294, 0.5255,  ..., 0.4471, 0.4431, 0.4314],
#           ...,
#           [0.5059, 0.5059, 0.5098,  ..., 0.4471, 0.4353, 0.4353],
#           [0.5059, 0.5098, 0.5176,  ..., 0.4431, 0.4353, 0.4392],
#           [0.5020, 0.5137, 0.5255,  ..., 0.4431, 0.4392, 0.4471]],
#
#          [[0.5412, 0.5255, 0.5176,  ..., 0.4667, 0.4510, 0.4353],
#           [0.5333, 0.5216, 0.5216,  ..., 0.4549, 0.4431, 0.4275],
#           [0.5176, 0.5176, 0.5255,  ..., 0.4392, 0.4353, 0.4235],
#           ...,
#           [0.5294, 0.5294, 0.5255,  ..., 0.4510, 0.4392, 0.4392],
#           [0.5294, 0.5333, 0.5333,  ..., 0.4471, 0.4392, 0.4431],
#           [0.5255, 0.5373, 0.5412,  ..., 0.4471, 0.4431, 0.4510]],
#
#          [[0.4941, 0.4784, 0.4824,  ..., 0.4118, 0.4078, 0.3882],
#           [0.4863, 0.4863, 0.4863,  ..., 0.4314, 0.4235, 0.4078],
#           [0.4824, 0.4824, 0.4941,  ..., 0.4431, 0.4392, 0.4275],
#           ...,
#           [0.5216, 0.5216, 0.5216,  ..., 0.4275, 0.4157, 0.4157],
#           [0.5216, 0.5255, 0.5294,  ..., 0.4235, 0.4157, 0.4196],
#           [0.5176, 0.5294, 0.5373,  ..., 0.4235, 0.4196, 0.4275]]],
#
#
#         ...,
#
#
#         [[[0.5059, 0.5020, 0.5059,  ..., 0.4980, 0.4941, 0.4941],
#           [0.5020, 0.4980, 0.5020,  ..., 0.4980, 0.4980, 0.4941],
#           [0.4941, 0.4941, 0.4941,  ..., 0.5059, 0.4980, 0.4941],
#           ...,
#           [0.5255, 0.5216, 0.5137,  ..., 0.5098, 0.5098, 0.5059],
#           [0.5176, 0.5176, 0.5176,  ..., 0.5098, 0.5098, 0.5059],
#           [0.5137, 0.5216, 0.5216,  ..., 0.5098, 0.5059, 0.5020]],
#
#          [[0.5098, 0.5059, 0.5059,  ..., 0.5098, 0.5059, 0.5059],
#           [0.5059, 0.5020, 0.5020,  ..., 0.5098, 0.5098, 0.5059],
#           [0.4980, 0.4980, 0.4941,  ..., 0.5098, 0.5137, 0.5098],
#           ...,
#           [0.5333, 0.5294, 0.5255,  ..., 0.5137, 0.5137, 0.5098],
#           [0.5255, 0.5294, 0.5294,  ..., 0.5137, 0.5137, 0.5098],
#           [0.5216, 0.5333, 0.5333,  ..., 0.5137, 0.5098, 0.5059]],
#
#          [[0.4902, 0.4863, 0.4980,  ..., 0.5294, 0.5255, 0.5255],
#           [0.4863, 0.4824, 0.4941,  ..., 0.5294, 0.5294, 0.5255],
#           [0.4784, 0.4784, 0.4863,  ..., 0.5255, 0.5255, 0.5216],
#           ...,
#           [0.5137, 0.5098, 0.4980,  ..., 0.4941, 0.4941, 0.4902],
#           [0.5059, 0.5020, 0.5020,  ..., 0.4941, 0.4941, 0.4902],
#           [0.5020, 0.5059, 0.5059,  ..., 0.4941, 0.4902, 0.4863]]],
#
#
#         [[[0.3451, 0.3412, 0.3451,  ..., 0.4078, 0.4157, 0.4196],
#           [0.3451, 0.3412, 0.3490,  ..., 0.4118, 0.4157, 0.4157],
#           [0.3451, 0.3490, 0.3529,  ..., 0.4118, 0.4157, 0.4157],
#           ...,
#           [0.4588, 0.4627, 0.4549,  ..., 0.4039, 0.4039, 0.4000],
#           [0.4588, 0.4588, 0.4510,  ..., 0.4078, 0.4078, 0.4039],
#           [0.4510, 0.4510, 0.4471,  ..., 0.4118, 0.4078, 0.4039]],
#
#          [[0.3843, 0.3804, 0.3843,  ..., 0.4078, 0.4157, 0.4196],
#           [0.3843, 0.3804, 0.3804,  ..., 0.4118, 0.4157, 0.4157],
#           [0.3843, 0.3843, 0.3882,  ..., 0.4118, 0.4157, 0.4157],
#           ...,
#           [0.4863, 0.4902, 0.4824,  ..., 0.4078, 0.4078, 0.4039],
#           [0.4863, 0.4863, 0.4784,  ..., 0.4118, 0.4118, 0.4078],
#           [0.4902, 0.4902, 0.4863,  ..., 0.4157, 0.4118, 0.4078]],
#
#          [[0.3882, 0.3843, 0.3882,  ..., 0.4157, 0.4235, 0.4275],
#           [0.3882, 0.3843, 0.3882,  ..., 0.4196, 0.4235, 0.4235],
#           [0.3804, 0.3804, 0.3843,  ..., 0.4118, 0.4157, 0.4157],
#           ...,
#           [0.4549, 0.4588, 0.4510,  ..., 0.3765, 0.3765, 0.3725],
#           [0.4549, 0.4549, 0.4471,  ..., 0.3804, 0.3804, 0.3765],
#           [0.4588, 0.4588, 0.4549,  ..., 0.3843, 0.3804, 0.3765]]],
#
#
#         [[[0.4392, 0.4392, 0.4431,  ..., 0.4196, 0.4196, 0.4000],
#           [0.4510, 0.4431, 0.4431,  ..., 0.4157, 0.4196, 0.4000],
#           [0.4549, 0.4431, 0.4431,  ..., 0.4039, 0.4118, 0.4000],
#           ...,
#           [0.4431, 0.4471, 0.4471,  ..., 0.4314, 0.4275, 0.4235],
#           [0.4431, 0.4431, 0.4471,  ..., 0.4353, 0.4314, 0.4275],
#           [0.4392, 0.4392, 0.4471,  ..., 0.4353, 0.4314, 0.4314]],
#
#          [[0.4745, 0.4745, 0.4784,  ..., 0.4353, 0.4314, 0.4118],
#           [0.4784, 0.4706, 0.4667,  ..., 0.4314, 0.4353, 0.4118],
#           [0.4824, 0.4706, 0.4706,  ..., 0.4235, 0.4314, 0.4196],
#           ...,
#           [0.4549, 0.4510, 0.4510,  ..., 0.4353, 0.4314, 0.4275],
#           [0.4549, 0.4549, 0.4510,  ..., 0.4392, 0.4353, 0.4314],
#           [0.4510, 0.4510, 0.4510,  ..., 0.4392, 0.4353, 0.4353]],
#
#          [[0.4549, 0.4549, 0.4588,  ..., 0.4471, 0.4588, 0.4471],
#           [0.4510, 0.4431, 0.4510,  ..., 0.4353, 0.4471, 0.4314],
#           [0.4510, 0.4392, 0.4431,  ..., 0.4078, 0.4157, 0.4039],
#           ...,
#           [0.4275, 0.4275, 0.4275,  ..., 0.4157, 0.4118, 0.4078],
#           [0.4275, 0.4275, 0.4275,  ..., 0.4196, 0.4157, 0.4118],
#           [0.4235, 0.4235, 0.4275,  ..., 0.4196, 0.4157, 0.4157]]]]), tensor([17,  3,  9,  0, 17,  3,  9,  9])]

# %%
import matplotlib.pyplot as plt

images,gt = next(iter(train_loader))

fig = plt.figure()
for i in range(8):
  plt.subplot(2,4,i+1)
  plt.tight_layout()
  npimg = images[i].numpy()
  npimg = (npimg - np.min(npimg))/np.ptp(npimg)
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.title("Ground Truth: {}".format(gt[i]))
  plt.xticks([])
  plt.yticks([])

# %%
class Lane_net(nn.Module):
    def __init__(self):
        super(Lane_net, self).__init__()

        # linear activation
        self.relu_layer = nn.ReLU(inplace=True)
        # max pool 
        self.pool = nn.MaxPool2d(kernel_size=4, stride=3)

        # conv2d(n_samples, channels, height, width)
        # first conv layer
        self.cnn_layer1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        
        # batch normalization
        self.batch1 = nn.BatchNorm2d(32)

        # second conv layer
        self.cnn_layer2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.batch2 = nn.BatchNorm2d(64)

        # third conv layer
        self.cnn_layer3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.batch3 = nn.BatchNorm2d(128)
        
        self.cnn_layer4 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.batch4 = nn.BatchNorm2d(128)

        self.linear_layer1 = nn.Linear(128*35, 2048)
        self.linear_layer2 = nn.Linear(2048,1024)
        self.linear_layer3 = nn.Linear(1024,18)
        

    def forward(self, x):
        # first conv layer
        x = self.cnn_layer1(x)
        x = self.batch1(x)
        x = self.relu_layer(x)
        x = self.pool(x)

        # second conv layer
        x = self.cnn_layer2(x)
        x = self.batch2(x)
        x = self.relu_layer(x)
        x = self.pool(x)

        # third conv layer
        x = self.cnn_layer3(x)
        x = self.batch3(x)
        x = self.relu_layer(x)
        x = self.pool(x)
        
        # third conv layer
        x = self.cnn_layer4(x)
        x = self.batch4(x)
        x = self.relu_layer(x)
        x = self.pool(x)

        # linear 
        x = x.view(x.size(0), -1)
        #print(x.size())
        x = self.linear_layer1(x)
        x = self.linear_layer2(x)
        x = self.linear_layer3(x)
        return x

# %%
class Lane_drop(nn.Module):
    def __init__(self):
        super(Lane_drop, self).__init__()

        # linear activation
        self.relu_layer = nn.ReLU(inplace=True)
        # max pool 
        self.pool = nn.MaxPool2d(kernel_size=4, stride=3)

        # conv2d(n_samples, channels, height, width)
        # first conv layer
        self.cnn_layer1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        
        # batch normalization
        self.batch1 = nn.BatchNorm2d(32)

        # second conv layer
        self.cnn_layer2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.batch2 = nn.BatchNorm2d(64)

        # third conv layer
        self.cnn_layer3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.batch3 = nn.BatchNorm2d(128)
        
        self.cnn_layer4 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.batch4 = nn.BatchNorm2d(128)

        self.linear_layer1 = nn.Linear(128*35, 2048)
        self.linear_layer2 = nn.Linear(2048,1024)
        self.linear_layer3 = nn.Linear(1024,18)
        self.dropout = nn.Dropout(0.25)

    def forward(self, x):
        # first conv layer
        x = self.cnn_layer1(x)
        x = self.batch1(x)
        x = self.relu_layer(x)
        x = self.pool(x)

        # second conv layer
        x = self.cnn_layer2(x)
        x = self.batch2(x)
        x = self.relu_layer(x)
        x = self.pool(x)

        # third conv layer
        x = self.cnn_layer3(x)
        x = self.batch3(x)
        x = self.relu_layer(x)
        x = self.pool(x)
        
        # third conv layer
        x = self.cnn_layer4(x)
        x = self.batch4(x)
        x = self.relu_layer(x)
        x = self.pool(x)

        # linear 
        x = x.view(x.size(0), -1)
        #print(x.size())
        x = self.linear_layer1(x)
        x = self.linear_layer2(x)
        x = self.linear_layer3(x)
        x = self.dropout(x)
        
        return x

# %%
# Load the model based on DenseNet-161
# lane_net = torchvision.models.mobilenet_v2(pretrained=True)
# lane_net = torchvision.models.densenet121(pretrained=True)

# # freeze the layers
# for param in lane_net.parameters():
#    param.requires_grad = False

# Modify the last layer for mobil
# num_ftrs = lane_net.classifier[1].in_features
# lane_net.classifier[1] = nn.Linear(num_ftrs, 18)

# modify for dense
# num_ftrs = lane_net.classifier.in_features
# lane_net.classifier = nn.Linear(num_ftrs, 18)


# lane net
# lane_net = Lane_net()

# lane net with dropout
lane_net = Lane_drop()

# send to gpu
lane_net = lane_net.to(device=device)

# PATH = 'dense_lane.pt'
# lane_net.load_state_dict(torch.load(PATH))
# lane_net.eval()
# optimizer = optim.SGD(draw_net.parameters(),lr=0.001, momentum=0.9)
optimizer = optim.Adam(lane_net.parameters(),lr=0.001)
criterion = nn.CrossEntropyLoss()
EPOCHS = 100

# %%
def test_acc():
    predictions = []
    gts = []
    for batch_idx, (X_batch, y_batch) in enumerate(test_loader):
        var_X_batch = Variable(X_batch).float().to(device=device)
        var_y_batch = Variable(y_batch).to(device=device)

        output = lane_net(var_X_batch)
        predicted = torch.max(output.data, 1)[1] 

        predictions.append(predicted.cpu().detach().numpy()[0])
        gts.append(var_y_batch.cpu().detach().numpy()[0])
        total_train_accuracy = (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 
    return total_train_accuracy

# %%
learning_curve = []
training_acc = []
highest_test_acc = 0
for epoch in range(EPOCHS):
    correct = 0
    for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
        var_X_batch = Variable(X_batch)
        var_X_batch = var_X_batch.to(device=device)
        var_y_batch = Variable(y_batch).to(device=device)
        optimizer.zero_grad()
    
        output = lane_net(var_X_batch)
        predicted = torch.max(output.data, 1)[1] 
        loss = criterion(output,var_y_batch)
        loss.backward()
        optimizer.step()
        
        # accuracy
        correct = (predicted == var_y_batch).sum()
        total = len(predicted)

        accuracy = (predicted == var_y_batch).sum()/len(predicted)*100
    
        # learning curve
        cel = loss.item()
        learning_curve.append(cel)
            
        training_acc.append(accuracy.item())
        correct = 0 
        total = 0
        if batch_idx % 10 == 0: 
          accuracy = accuracy.item()
          currently_run = batch_idx*len(X_batch)
          data_total = len(train_loader.dataset)
          percent_of_data_run = 100.*batch_idx / len(train_loader)
          print('Epoch: {}[{}/{} ({:.0f}%)]\t Accuracy:{:.3f}%\t Error:{:.2f}'.format(
              epoch, currently_run, data_total, percent_of_data_run, accuracy, cel))
    epoch_test = test_acc()
    print("EPOCH:" + str(epoch) + ", test_accuracy: " + str(epoch_test))
    if epoch_test > highest_test_acc:
        print(str(epoch_test) + ">" + str(highest_test_acc))
        highest_test_acc = test_acc()
        PATH = 'lane' + str(epoch) + 'epoch.pt'
        torch.save(lane_net.state_dict(), PATH)
# Out:
# Epoch: 0[0/5717 (0%)]	 Accuracy:0.000%	 Error:2.92
# Epoch: 0[80/5717 (1%)]	 Accuracy:12.500%	 Error:23.18
# Epoch: 0[160/5717 (3%)]	 Accuracy:0.000%	 Error:30.01
# Epoch: 0[240/5717 (4%)]	 Accuracy:37.500%	 Error:7.27
# Epoch: 0[320/5717 (6%)]	 Accuracy:0.000%	 Error:8.30
# Epoch: 0[400/5717 (7%)]	 Accuracy:0.000%	 Error:8.45
# Epoch: 0[480/5717 (8%)]	 Accuracy:25.000%	 Error:8.62
# Epoch: 0[560/5717 (10%)]	 Accuracy:25.000%	 Error:8.44
# Epoch: 0[640/5717 (11%)]	 Accuracy:0.000%	 Error:8.51
# Epoch: 0[720/5717 (13%)]	 Accuracy:12.500%	 Error:2.46
# Epoch: 0[800/5717 (14%)]	 Accuracy:12.500%	 Error:3.31
# Epoch: 0[880/5717 (15%)]	 Accuracy:37.500%	 Error:2.09
# Epoch: 0[960/5717 (17%)]	 Accuracy:37.500%	 Error:5.21
# Epoch: 0[1040/5717 (18%)]	 Accuracy:25.000%	 Error:3.76
# Epoch: 0[1120/5717 (20%)]	 Accuracy:12.500%	 Error:3.56
# Epoch: 0[1200/5717 (21%)]	 Accuracy:37.500%	 Error:2.18
# Epoch: 0[1280/5717 (22%)]	 Accuracy:12.500%	 Error:3.70
# Epoch: 0[1360/5717 (24%)]	 Accuracy:50.000%	 Error:1.82
# Epoch: 0[1440/5717 (25%)]	 Accuracy:37.500%	 Error:1.68
# Epoch: 0[1520/5717 (27%)]	 Accuracy:50.000%	 Error:1.68
# Epoch: 0[1600/5717 (28%)]	 Accuracy:25.000%	 Error:4.69
# Epoch: 0[1680/5717 (29%)]	 Accuracy:25.000%	 Error:2.91
# Epoch: 0[1760/5717 (31%)]	 Accuracy:25.000%	 Error:2.08
# Epoch: 0[1840/5717 (32%)]	 Accuracy:37.500%	 Error:2.06
# Epoch: 0[1920/5717 (34%)]	 Accuracy:12.500%	 Error:1.88
# Epoch: 0[2000/5717 (35%)]	 Accuracy:25.000%	 Error:3.49
# Epoch: 0[2080/5717 (36%)]	 Accuracy:62.500%	 Error:1.45
# Epoch: 0[2160/5717 (38%)]	 Accuracy:25.000%	 Error:2.99
# Epoch: 0[2240/5717 (39%)]	 Accuracy:37.500%	 Error:1.86
# Epoch: 0[2320/5717 (41%)]	 Accuracy:62.500%	 Error:1.72
# Epoch: 0[2400/5717 (42%)]	 Accuracy:37.500%	 Error:2.75
# Epoch: 0[2480/5717 (43%)]	 Accuracy:12.500%	 Error:2.49
# Epoch: 0[2560/5717 (45%)]	 Accuracy:37.500%	 Error:3.23
# Epoch: 0[2640/5717 (46%)]	 Accuracy:25.000%	 Error:2.87
# Epoch: 0[2720/5717 (48%)]	 Accuracy:37.500%	 Error:1.78
# Epoch: 0[2800/5717 (49%)]	 Accuracy:37.500%	 Error:2.01
# Epoch: 0[2880/5717 (50%)]	 Accuracy:25.000%	 Error:2.32
# Epoch: 0[2960/5717 (52%)]	 Accuracy:50.000%	 Error:1.73
# Epoch: 0[3040/5717 (53%)]	 Accuracy:37.500%	 Error:2.56
# Epoch: 0[3120/5717 (55%)]	 Accuracy:25.000%	 Error:2.59
# Epoch: 0[3200/5717 (56%)]	 Accuracy:37.500%	 Error:2.28
# Epoch: 0[3280/5717 (57%)]	 Accuracy:25.000%	 Error:1.70
# Epoch: 0[3360/5717 (59%)]	 Accuracy:12.500%	 Error:3.35
# Epoch: 0[3440/5717 (60%)]	 Accuracy:37.500%	 Error:2.73
# Epoch: 0[3520/5717 (62%)]	 Accuracy:12.500%	 Error:2.46
# Epoch: 0[3600/5717 (63%)]	 Accuracy:25.000%	 Error:1.87
# Epoch: 0[3680/5717 (64%)]	 Accuracy:50.000%	 Error:1.77
# Epoch: 0[3760/5717 (66%)]	 Accuracy:50.000%	 Error:1.70
# Epoch: 0[3840/5717 (67%)]	 Accuracy:50.000%	 Error:1.62
# Epoch: 0[3920/5717 (69%)]	 Accuracy:25.000%	 Error:2.43
# Epoch: 0[4000/5717 (70%)]	 Accuracy:50.000%	 Error:3.88
# Epoch: 0[4080/5717 (71%)]	 Accuracy:25.000%	 Error:2.29
# Epoch: 0[4160/5717 (73%)]	 Accuracy:37.500%	 Error:2.04
# Epoch: 0[4240/5717 (74%)]	 Accuracy:12.500%	 Error:2.50
# Epoch: 0[4320/5717 (76%)]	 Accuracy:50.000%	 Error:1.41
# Epoch: 0[4400/5717 (77%)]	 Accuracy:25.000%	 Error:1.94
# Epoch: 0[4480/5717 (78%)]	 Accuracy:12.500%	 Error:2.88
# Epoch: 0[4560/5717 (80%)]	 Accuracy:12.500%	 Error:2.77
# Epoch: 0[4640/5717 (81%)]	 Accuracy:12.500%	 Error:3.07
# Epoch: 0[4720/5717 (83%)]	 Accuracy:37.500%	 Error:1.88
# Epoch: 0[4800/5717 (84%)]	 Accuracy:50.000%	 Error:1.79
# Epoch: 0[4880/5717 (85%)]	 Accuracy:50.000%	 Error:2.35
# Epoch: 0[4960/5717 (87%)]	 Accuracy:75.000%	 Error:1.25
# Epoch: 0[5040/5717 (88%)]	 Accuracy:37.500%	 Error:2.26
# Epoch: 0[5120/5717 (90%)]	 Accuracy:12.500%	 Error:2.53
# Epoch: 0[5200/5717 (91%)]	 Accuracy:37.500%	 Error:1.62
# Epoch: 0[5280/5717 (92%)]	 Accuracy:37.500%	 Error:1.72
# Epoch: 0[5360/5717 (94%)]	 Accuracy:25.000%	 Error:1.84
# Epoch: 0[5440/5717 (95%)]	 Accuracy:25.000%	 Error:1.86
# Epoch: 0[5520/5717 (97%)]	 Accuracy:62.500%	 Error:1.31
# Epoch: 0[5600/5717 (98%)]	 Accuracy:50.000%	 Error:1.42
# Epoch: 0[5680/5717 (99%)]	 Accuracy:37.500%	 Error:2.68
# EPOCH:0, test_accuracy: 28.037383177570092
# 28.037383177570092>0
# Epoch: 1[0/5717 (0%)]	 Accuracy:37.500%	 Error:1.92
# Epoch: 1[80/5717 (1%)]	 Accuracy:37.500%	 Error:2.61
# Epoch: 1[160/5717 (3%)]	 Accuracy:12.500%	 Error:2.45
# Epoch: 1[240/5717 (4%)]	 Accuracy:25.000%	 Error:1.93
# Epoch: 1[320/5717 (6%)]	 Accuracy:62.500%	 Error:1.45
# Epoch: 1[400/5717 (7%)]	 Accuracy:37.500%	 Error:1.83
# Epoch: 1[480/5717 (8%)]	 Accuracy:25.000%	 Error:1.80
# Epoch: 1[560/5717 (10%)]	 Accuracy:62.500%	 Error:1.36
# Epoch: 1[640/5717 (11%)]	 Accuracy:37.500%	 Error:1.53
# Epoch: 1[720/5717 (13%)]	 Accuracy:62.500%	 Error:1.48
# Epoch: 1[800/5717 (14%)]	 Accuracy:50.000%	 Error:1.73
# Epoch: 1[880/5717 (15%)]	 Accuracy:37.500%	 Error:1.82
# Epoch: 1[960/5717 (17%)]	 Accuracy:75.000%	 Error:0.92
# Epoch: 1[1040/5717 (18%)]	 Accuracy:50.000%	 Error:1.72
# Epoch: 1[1120/5717 (20%)]	 Accuracy:37.500%	 Error:1.96
# Epoch: 1[1200/5717 (21%)]	 Accuracy:37.500%	 Error:1.59
# Epoch: 1[1280/5717 (22%)]	 Accuracy:0.000%	 Error:3.17
# Epoch: 1[1360/5717 (24%)]	 Accuracy:25.000%	 Error:2.26
# Epoch: 1[1440/5717 (25%)]	 Accuracy:50.000%	 Error:1.57
# Epoch: 1[1520/5717 (27%)]	 Accuracy:25.000%	 Error:3.08
# Epoch: 1[1600/5717 (28%)]	 Accuracy:37.500%	 Error:1.98
# Epoch: 1[1680/5717 (29%)]	 Accuracy:50.000%	 Error:1.93
# Epoch: 1[1760/5717 (31%)]	 Accuracy:50.000%	 Error:1.83
# Epoch: 1[1840/5717 (32%)]	 Accuracy:25.000%	 Error:2.80
# Epoch: 1[1920/5717 (34%)]	 Accuracy:37.500%	 Error:1.55
# Epoch: 1[2000/5717 (35%)]	 Accuracy:50.000%	 Error:1.43
# Epoch: 1[2080/5717 (36%)]	 Accuracy:50.000%	 Error:1.78
# Epoch: 1[2160/5717 (38%)]	 Accuracy:12.500%	 Error:1.64
# Epoch: 1[2240/5717 (39%)]	 Accuracy:25.000%	 Error:2.46
# Epoch: 1[2320/5717 (41%)]	 Accuracy:37.500%	 Error:1.77
# Epoch: 1[2400/5717 (42%)]	 Accuracy:37.500%	 Error:2.46
# Epoch: 1[2480/5717 (43%)]	 Accuracy:25.000%	 Error:2.59
# Epoch: 1[2560/5717 (45%)]	 Accuracy:25.000%	 Error:1.92
# Epoch: 1[2640/5717 (46%)]	 Accuracy:50.000%	 Error:1.53
# Epoch: 1[2720/5717 (48%)]	 Accuracy:25.000%	 Error:2.01
# Epoch: 1[2800/5717 (49%)]	 Accuracy:12.500%	 Error:2.30
# Epoch: 1[2880/5717 (50%)]	 Accuracy:25.000%	 Error:2.59
# Epoch: 1[2960/5717 (52%)]	 Accuracy:37.500%	 Error:1.58
# Epoch: 1[3040/5717 (53%)]	 Accuracy:50.000%	 Error:1.46
# Epoch: 1[3120/5717 (55%)]	 Accuracy:50.000%	 Error:2.15
# Epoch: 1[3200/5717 (56%)]	 Accuracy:37.500%	 Error:2.04
# Epoch: 1[3280/5717 (57%)]	 Accuracy:37.500%	 Error:1.60
# Epoch: 1[3360/5717 (59%)]	 Accuracy:37.500%	 Error:1.61
# Epoch: 1[3440/5717 (60%)]	 Accuracy:12.500%	 Error:2.16
# Epoch: 1[3520/5717 (62%)]	 Accuracy:50.000%	 Error:1.56
# Epoch: 1[3600/5717 (63%)]	 Accuracy:37.500%	 Error:2.29
# Epoch: 1[3680/5717 (64%)]	 Accuracy:62.500%	 Error:1.37
# Epoch: 1[3760/5717 (66%)]	 Accuracy:25.000%	 Error:3.23
# Epoch: 1[3840/5717 (67%)]	 Accuracy:37.500%	 Error:1.97
# Epoch: 1[3920/5717 (69%)]	 Accuracy:37.500%	 Error:1.85
# Epoch: 1[4000/5717 (70%)]	 Accuracy:62.500%	 Error:1.27
# Epoch: 1[4080/5717 (71%)]	 Accuracy:37.500%	 Error:2.36
# Epoch: 1[4160/5717 (73%)]	 Accuracy:37.500%	 Error:1.83
# Epoch: 1[4240/5717 (74%)]	 Accuracy:62.500%	 Error:1.05
# Epoch: 1[4320/5717 (76%)]	 Accuracy:25.000%	 Error:1.90
# Epoch: 1[4400/5717 (77%)]	 Accuracy:37.500%	 Error:2.19
# Epoch: 1[4480/5717 (78%)]	 Accuracy:50.000%	 Error:1.57
# Epoch: 1[4560/5717 (80%)]	 Accuracy:50.000%	 Error:1.55
# Epoch: 1[4640/5717 (81%)]	 Accuracy:50.000%	 Error:1.92
# Epoch: 1[4720/5717 (83%)]	 Accuracy:50.000%	 Error:1.99
# Epoch: 1[4800/5717 (84%)]	 Accuracy:62.500%	 Error:1.13
# Epoch: 1[4880/5717 (85%)]	 Accuracy:62.500%	 Error:1.23
# Epoch: 1[4960/5717 (87%)]	 Accuracy:62.500%	 Error:1.07
# Epoch: 1[5040/5717 (88%)]	 Accuracy:25.000%	 Error:1.66
# Epoch: 1[5120/5717 (90%)]	 Accuracy:50.000%	 Error:1.46
# Epoch: 1[5200/5717 (91%)]	 Accuracy:50.000%	 Error:1.33
# Epoch: 1[5280/5717 (92%)]	 Accuracy:62.500%	 Error:1.06
# Epoch: 1[5360/5717 (94%)]	 Accuracy:25.000%	 Error:2.37
# Epoch: 1[5440/5717 (95%)]	 Accuracy:37.500%	 Error:2.14
# Epoch: 1[5520/5717 (97%)]	 Accuracy:50.000%	 Error:2.32
# Epoch: 1[5600/5717 (98%)]	 Accuracy:37.500%	 Error:1.78
# Epoch: 1[5680/5717 (99%)]	 Accuracy:50.000%	 Error:1.53
# EPOCH:1, test_accuracy: 46.728971962616825
# 46.728971962616825>36.44859813084112
# Epoch: 2[0/5717 (0%)]	 Accuracy:37.500%	 Error:1.81
# Epoch: 2[80/5717 (1%)]	 Accuracy:62.500%	 Error:1.62
# Epoch: 2[160/5717 (3%)]	 Accuracy:62.500%	 Error:0.92
# Epoch: 2[240/5717 (4%)]	 Accuracy:12.500%	 Error:2.70
# Epoch: 2[320/5717 (6%)]	 Accuracy:50.000%	 Error:1.55
# Epoch: 2[400/5717 (7%)]	 Accuracy:37.500%	 Error:1.69
# Epoch: 2[480/5717 (8%)]	 Accuracy:50.000%	 Error:1.61
# Epoch: 2[560/5717 (10%)]	 Accuracy:37.500%	 Error:1.97
# Epoch: 2[640/5717 (11%)]	 Accuracy:50.000%	 Error:1.00
# Epoch: 2[720/5717 (13%)]	 Accuracy:37.500%	 Error:2.26
# Epoch: 2[800/5717 (14%)]	 Accuracy:62.500%	 Error:1.51
# Epoch: 2[880/5717 (15%)]	 Accuracy:50.000%	 Error:2.10
# Epoch: 2[960/5717 (17%)]	 Accuracy:37.500%	 Error:2.31
# Epoch: 2[1040/5717 (18%)]	 Accuracy:37.500%	 Error:1.43
# Epoch: 2[1120/5717 (20%)]	 Accuracy:50.000%	 Error:2.01
# Epoch: 2[1200/5717 (21%)]	 Accuracy:12.500%	 Error:2.45
# Epoch: 2[1280/5717 (22%)]	 Accuracy:25.000%	 Error:1.69
# Epoch: 2[1360/5717 (24%)]	 Accuracy:37.500%	 Error:1.73
# Epoch: 2[1440/5717 (25%)]	 Accuracy:50.000%	 Error:1.63
# Epoch: 2[1520/5717 (27%)]	 Accuracy:25.000%	 Error:2.10
# Epoch: 2[1600/5717 (28%)]	 Accuracy:50.000%	 Error:1.85
# Epoch: 2[1680/5717 (29%)]	 Accuracy:37.500%	 Error:2.15
# Epoch: 2[1760/5717 (31%)]	 Accuracy:50.000%	 Error:1.96
# Epoch: 2[1840/5717 (32%)]	 Accuracy:12.500%	 Error:2.24
# Epoch: 2[1920/5717 (34%)]	 Accuracy:50.000%	 Error:1.35
# Epoch: 2[2000/5717 (35%)]	 Accuracy:25.000%	 Error:2.19
# Epoch: 2[2080/5717 (36%)]	 Accuracy:62.500%	 Error:1.32
# Epoch: 2[2160/5717 (38%)]	 Accuracy:62.500%	 Error:0.93
# Epoch: 2[2240/5717 (39%)]	 Accuracy:25.000%	 Error:2.06
# Epoch: 2[2320/5717 (41%)]	 Accuracy:100.000%	 Error:0.41
# Epoch: 2[2400/5717 (42%)]	 Accuracy:62.500%	 Error:1.46
# Epoch: 2[2480/5717 (43%)]	 Accuracy:37.500%	 Error:1.72
# Epoch: 2[2560/5717 (45%)]	 Accuracy:25.000%	 Error:2.46
# Epoch: 2[2640/5717 (46%)]	 Accuracy:25.000%	 Error:1.70
# Epoch: 2[2720/5717 (48%)]	 Accuracy:50.000%	 Error:1.91
# Epoch: 2[2800/5717 (49%)]	 Accuracy:25.000%	 Error:2.54
# Epoch: 2[2880/5717 (50%)]	 Accuracy:37.500%	 Error:2.01
# Epoch: 2[2960/5717 (52%)]	 Accuracy:25.000%	 Error:2.45
# Epoch: 2[3040/5717 (53%)]	 Accuracy:12.500%	 Error:2.21
# Epoch: 2[3120/5717 (55%)]	 Accuracy:50.000%	 Error:1.49
# Epoch: 2[3200/5717 (56%)]	 Accuracy:75.000%	 Error:1.15
# Epoch: 2[3280/5717 (57%)]	 Accuracy:25.000%	 Error:2.05
# Epoch: 2[3360/5717 (59%)]	 Accuracy:37.500%	 Error:1.94
# Epoch: 2[3440/5717 (60%)]	 Accuracy:37.500%	 Error:2.13
# Epoch: 2[3520/5717 (62%)]	 Accuracy:37.500%	 Error:1.90
# Epoch: 2[3600/5717 (63%)]	 Accuracy:75.000%	 Error:1.07
# Epoch: 2[3680/5717 (64%)]	 Accuracy:62.500%	 Error:1.52
# Epoch: 2[3760/5717 (66%)]	 Accuracy:75.000%	 Error:0.67
# Epoch: 2[3840/5717 (67%)]	 Accuracy:37.500%	 Error:1.53
# Epoch: 2[3920/5717 (69%)]	 Accuracy:25.000%	 Error:2.49
# Epoch: 2[4000/5717 (70%)]	 Accuracy:37.500%	 Error:1.73
# Epoch: 2[4080/5717 (71%)]	 Accuracy:25.000%	 Error:2.35
# Epoch: 2[4160/5717 (73%)]	 Accuracy:50.000%	 Error:1.26
# Epoch: 2[4240/5717 (74%)]	 Accuracy:50.000%	 Error:2.02
# Epoch: 2[4320/5717 (76%)]	 Accuracy:62.500%	 Error:1.26
# Epoch: 2[4400/5717 (77%)]	 Accuracy:37.500%	 Error:2.21
# Epoch: 2[4480/5717 (78%)]	 Accuracy:50.000%	 Error:2.04
# Epoch: 2[4560/5717 (80%)]	 Accuracy:37.500%	 Error:1.26
# Epoch: 2[4640/5717 (81%)]	 Accuracy:62.500%	 Error:1.61
# Epoch: 2[4720/5717 (83%)]	 Accuracy:87.500%	 Error:0.75
# Epoch: 2[4800/5717 (84%)]	 Accuracy:37.500%	 Error:1.41
# Epoch: 2[4880/5717 (85%)]	 Accuracy:50.000%	 Error:1.74
# Epoch: 2[4960/5717 (87%)]	 Accuracy:62.500%	 Error:1.44
# Epoch: 2[5040/5717 (88%)]	 Accuracy:50.000%	 Error:1.46
# Epoch: 2[5120/5717 (90%)]	 Accuracy:37.500%	 Error:1.90
# Epoch: 2[5200/5717 (91%)]	 Accuracy:75.000%	 Error:0.94
# Epoch: 2[5280/5717 (92%)]	 Accuracy:62.500%	 Error:0.96
# Epoch: 2[5360/5717 (94%)]	 Accuracy:37.500%	 Error:1.90
# Epoch: 2[5440/5717 (95%)]	 Accuracy:25.000%	 Error:2.48
# Epoch: 2[5520/5717 (97%)]	 Accuracy:37.500%	 Error:2.10
# Epoch: 2[5600/5717 (98%)]	 Accuracy:62.500%	 Error:1.27
# Epoch: 2[5680/5717 (99%)]	 Accuracy:50.000%	 Error:1.22
# EPOCH:2, test_accuracy: 42.99065420560748
# Epoch: 3[0/5717 (0%)]	 Accuracy:75.000%	 Error:0.74
# Epoch: 3[80/5717 (1%)]	 Accuracy:62.500%	 Error:1.54
# Epoch: 3[160/5717 (3%)]	 Accuracy:37.500%	 Error:1.79
# Epoch: 3[240/5717 (4%)]	 Accuracy:50.000%	 Error:1.49
# Epoch: 3[320/5717 (6%)]	 Accuracy:25.000%	 Error:2.47
# Epoch: 3[400/5717 (7%)]	 Accuracy:37.500%	 Error:1.83
# Epoch: 3[480/5717 (8%)]	 Accuracy:50.000%	 Error:2.25
# Epoch: 3[560/5717 (10%)]	 Accuracy:62.500%	 Error:1.18
# Epoch: 3[640/5717 (11%)]	 Accuracy:75.000%	 Error:1.37
# Epoch: 3[720/5717 (13%)]	 Accuracy:50.000%	 Error:1.70
# Epoch: 3[800/5717 (14%)]	 Accuracy:62.500%	 Error:1.67
# Epoch: 3[880/5717 (15%)]	 Accuracy:62.500%	 Error:1.23
# Epoch: 3[960/5717 (17%)]	 Accuracy:37.500%	 Error:1.75
# Epoch: 3[1040/5717 (18%)]	 Accuracy:37.500%	 Error:1.82
# Epoch: 3[1120/5717 (20%)]	 Accuracy:25.000%	 Error:1.87
# Epoch: 3[1200/5717 (21%)]	 Accuracy:37.500%	 Error:1.92
# Epoch: 3[1280/5717 (22%)]	 Accuracy:37.500%	 Error:1.60
# Epoch: 3[1360/5717 (24%)]	 Accuracy:75.000%	 Error:1.04
# Epoch: 3[1440/5717 (25%)]	 Accuracy:62.500%	 Error:1.05
# Epoch: 3[1520/5717 (27%)]	 Accuracy:37.500%	 Error:3.00
# Epoch: 3[1600/5717 (28%)]	 Accuracy:62.500%	 Error:1.27
# Epoch: 3[1680/5717 (29%)]	 Accuracy:50.000%	 Error:1.43
# Epoch: 3[1760/5717 (31%)]	 Accuracy:37.500%	 Error:1.85
# Epoch: 3[1840/5717 (32%)]	 Accuracy:75.000%	 Error:0.92
# Epoch: 3[1920/5717 (34%)]	 Accuracy:25.000%	 Error:2.09
# Epoch: 3[2000/5717 (35%)]	 Accuracy:37.500%	 Error:2.29
# Epoch: 3[2080/5717 (36%)]	 Accuracy:50.000%	 Error:1.41
# Epoch: 3[2160/5717 (38%)]	 Accuracy:37.500%	 Error:1.76
# Epoch: 3[2240/5717 (39%)]	 Accuracy:50.000%	 Error:1.36
# Epoch: 3[2320/5717 (41%)]	 Accuracy:62.500%	 Error:1.31
# Epoch: 3[2400/5717 (42%)]	 Accuracy:50.000%	 Error:1.33
# Epoch: 3[2480/5717 (43%)]	 Accuracy:37.500%	 Error:1.90
# Epoch: 3[2560/5717 (45%)]	 Accuracy:37.500%	 Error:1.50
# Epoch: 3[2640/5717 (46%)]	 Accuracy:50.000%	 Error:1.37
# Epoch: 3[2720/5717 (48%)]	 Accuracy:25.000%	 Error:1.86
# Epoch: 3[2800/5717 (49%)]	 Accuracy:75.000%	 Error:0.97
# Epoch: 3[2880/5717 (50%)]	 Accuracy:25.000%	 Error:2.07
# Epoch: 3[2960/5717 (52%)]	 Accuracy:50.000%	 Error:1.54
# Epoch: 3[3040/5717 (53%)]	 Accuracy:50.000%	 Error:1.54
# Epoch: 3[3120/5717 (55%)]	 Accuracy:50.000%	 Error:1.30
# Epoch: 3[3200/5717 (56%)]	 Accuracy:50.000%	 Error:1.54
# Epoch: 3[3280/5717 (57%)]	 Accuracy:62.500%	 Error:1.99
# Epoch: 3[3360/5717 (59%)]	 Accuracy:75.000%	 Error:0.79
# Epoch: 3[3440/5717 (60%)]	 Accuracy:50.000%	 Error:1.52
# Epoch: 3[3520/5717 (62%)]	 Accuracy:37.500%	 Error:1.55
# Epoch: 3[3600/5717 (63%)]	 Accuracy:50.000%	 Error:1.25
# Epoch: 3[3680/5717 (64%)]	 Accuracy:62.500%	 Error:1.42
# Epoch: 3[3760/5717 (66%)]	 Accuracy:25.000%	 Error:1.84
# Epoch: 3[3840/5717 (67%)]	 Accuracy:50.000%	 Error:1.06
# Epoch: 3[3920/5717 (69%)]	 Accuracy:25.000%	 Error:1.81
# Epoch: 3[4000/5717 (70%)]	 Accuracy:25.000%	 Error:2.52
# Epoch: 3[4080/5717 (71%)]	 Accuracy:25.000%	 Error:1.66
# Epoch: 3[4160/5717 (73%)]	 Accuracy:37.500%	 Error:2.27
# Epoch: 3[4240/5717 (74%)]	 Accuracy:62.500%	 Error:1.40
# Epoch: 3[4320/5717 (76%)]	 Accuracy:62.500%	 Error:1.15
# Epoch: 3[4400/5717 (77%)]	 Accuracy:62.500%	 Error:2.33
# Epoch: 3[4480/5717 (78%)]	 Accuracy:50.000%	 Error:1.64
# Epoch: 3[4560/5717 (80%)]	 Accuracy:62.500%	 Error:1.38
# Epoch: 3[4640/5717 (81%)]	 Accuracy:62.500%	 Error:1.40
# Epoch: 3[4720/5717 (83%)]	 Accuracy:75.000%	 Error:0.87
# Epoch: 3[4800/5717 (84%)]	 Accuracy:62.500%	 Error:1.11
# Epoch: 3[4880/5717 (85%)]	 Accuracy:87.500%	 Error:0.71
# Epoch: 3[4960/5717 (87%)]	 Accuracy:62.500%	 Error:0.97
# Epoch: 3[5040/5717 (88%)]	 Accuracy:37.500%	 Error:1.75
# Epoch: 3[5120/5717 (90%)]	 Accuracy:62.500%	 Error:1.01
# Epoch: 3[5200/5717 (91%)]	 Accuracy:37.500%	 Error:1.65
# Epoch: 3[5280/5717 (92%)]	 Accuracy:50.000%	 Error:1.31
# Epoch: 3[5360/5717 (94%)]	 Accuracy:25.000%	 Error:1.94
# Epoch: 3[5440/5717 (95%)]	 Accuracy:50.000%	 Error:1.85
# Epoch: 3[5520/5717 (97%)]	 Accuracy:62.500%	 Error:1.28
# Epoch: 3[5600/5717 (98%)]	 Accuracy:37.500%	 Error:1.60
# Epoch: 3[5680/5717 (99%)]	 Accuracy:37.500%	 Error:1.50
# EPOCH:3, test_accuracy: 54.20560747663551
# 54.20560747663551>45.794392523364486
# Epoch: 4[0/5717 (0%)]	 Accuracy:75.000%	 Error:0.86
# Epoch: 4[80/5717 (1%)]	 Accuracy:62.500%	 Error:0.93
# Epoch: 4[160/5717 (3%)]	 Accuracy:62.500%	 Error:1.14
# Epoch: 4[240/5717 (4%)]	 Accuracy:62.500%	 Error:1.03
# Epoch: 4[320/5717 (6%)]	 Accuracy:37.500%	 Error:1.39
# Epoch: 4[400/5717 (7%)]	 Accuracy:37.500%	 Error:1.60
# Epoch: 4[480/5717 (8%)]	 Accuracy:62.500%	 Error:1.31
# Epoch: 4[560/5717 (10%)]	 Accuracy:87.500%	 Error:0.68
# Epoch: 4[640/5717 (11%)]	 Accuracy:50.000%	 Error:1.32
# Epoch: 4[720/5717 (13%)]	 Accuracy:62.500%	 Error:1.08
# Epoch: 4[800/5717 (14%)]	 Accuracy:62.500%	 Error:0.96
# Epoch: 4[880/5717 (15%)]	 Accuracy:37.500%	 Error:2.60
# Epoch: 4[960/5717 (17%)]	 Accuracy:62.500%	 Error:1.25
# Epoch: 4[1040/5717 (18%)]	 Accuracy:75.000%	 Error:0.69
# Epoch: 4[1120/5717 (20%)]	 Accuracy:50.000%	 Error:1.23
# Epoch: 4[1200/5717 (21%)]	 Accuracy:62.500%	 Error:0.97
# Epoch: 4[1280/5717 (22%)]	 Accuracy:37.500%	 Error:2.11
# Epoch: 4[1360/5717 (24%)]	 Accuracy:75.000%	 Error:0.98
# Epoch: 4[1440/5717 (25%)]	 Accuracy:50.000%	 Error:1.61
# Epoch: 4[1520/5717 (27%)]	 Accuracy:62.500%	 Error:1.60
# Epoch: 4[1600/5717 (28%)]	 Accuracy:87.500%	 Error:0.62
# Epoch: 4[1680/5717 (29%)]	 Accuracy:37.500%	 Error:1.68
# Epoch: 4[1760/5717 (31%)]	 Accuracy:25.000%	 Error:1.53
# Epoch: 4[1840/5717 (32%)]	 Accuracy:62.500%	 Error:0.94
# Epoch: 4[1920/5717 (34%)]	 Accuracy:37.500%	 Error:2.07
# Epoch: 4[2000/5717 (35%)]	 Accuracy:37.500%	 Error:2.20
# Epoch: 4[2080/5717 (36%)]	 Accuracy:62.500%	 Error:0.86
# Epoch: 4[2160/5717 (38%)]	 Accuracy:12.500%	 Error:2.93
# Epoch: 4[2240/5717 (39%)]	 Accuracy:62.500%	 Error:1.44
# Epoch: 4[2320/5717 (41%)]	 Accuracy:50.000%	 Error:1.39
# Epoch: 4[2400/5717 (42%)]	 Accuracy:37.500%	 Error:1.31
# Epoch: 4[2480/5717 (43%)]	 Accuracy:50.000%	 Error:1.28
# Epoch: 4[2560/5717 (45%)]	 Accuracy:62.500%	 Error:1.59
# Epoch: 4[2640/5717 (46%)]	 Accuracy:25.000%	 Error:2.87
# Epoch: 4[2720/5717 (48%)]	 Accuracy:75.000%	 Error:0.80
# Epoch: 4[2800/5717 (49%)]	 Accuracy:62.500%	 Error:1.13
# Epoch: 4[2880/5717 (50%)]	 Accuracy:50.000%	 Error:1.49
# Epoch: 4[2960/5717 (52%)]	 Accuracy:25.000%	 Error:2.35
# Epoch: 4[3040/5717 (53%)]	 Accuracy:75.000%	 Error:1.07
# Epoch: 4[3120/5717 (55%)]	 Accuracy:37.500%	 Error:1.70
# Epoch: 4[3200/5717 (56%)]	 Accuracy:100.000%	 Error:0.41
# Epoch: 4[3280/5717 (57%)]	 Accuracy:62.500%	 Error:1.20
# Epoch: 4[3360/5717 (59%)]	 Accuracy:37.500%	 Error:1.48
# Epoch: 4[3440/5717 (60%)]	 Accuracy:87.500%	 Error:0.40
# Epoch: 4[3520/5717 (62%)]	 Accuracy:50.000%	 Error:1.17
# Epoch: 4[3600/5717 (63%)]	 Accuracy:62.500%	 Error:0.86
# Epoch: 4[3680/5717 (64%)]	 Accuracy:37.500%	 Error:2.07
# Epoch: 4[3760/5717 (66%)]	 Accuracy:50.000%	 Error:1.30
# Epoch: 4[3840/5717 (67%)]	 Accuracy:50.000%	 Error:1.35
# Epoch: 4[3920/5717 (69%)]	 Accuracy:37.500%	 Error:1.44
# Epoch: 4[4000/5717 (70%)]	 Accuracy:37.500%	 Error:1.42
# Epoch: 4[4080/5717 (71%)]	 Accuracy:62.500%	 Error:0.91
# Epoch: 4[4160/5717 (73%)]	 Accuracy:75.000%	 Error:0.63
# Epoch: 4[4240/5717 (74%)]	 Accuracy:25.000%	 Error:1.80
# Epoch: 4[4320/5717 (76%)]	 Accuracy:62.500%	 Error:1.37
# Epoch: 4[4400/5717 (77%)]	 Accuracy:75.000%	 Error:1.10
# Epoch: 4[4480/5717 (78%)]	 Accuracy:37.500%	 Error:1.56
# Epoch: 4[4560/5717 (80%)]	 Accuracy:37.500%	 Error:2.03
# Epoch: 4[4640/5717 (81%)]	 Accuracy:50.000%	 Error:1.49
# Epoch: 4[4720/5717 (83%)]	 Accuracy:50.000%	 Error:1.11
# Epoch: 4[4800/5717 (84%)]	 Accuracy:87.500%	 Error:0.44
# Epoch: 4[4880/5717 (85%)]	 Accuracy:50.000%	 Error:1.30
# Epoch: 4[4960/5717 (87%)]	 Accuracy:87.500%	 Error:0.79
# Epoch: 4[5040/5717 (88%)]	 Accuracy:50.000%	 Error:1.47
# Epoch: 4[5120/5717 (90%)]	 Accuracy:75.000%	 Error:1.04
# Epoch: 4[5200/5717 (91%)]	 Accuracy:75.000%	 Error:1.08
# Epoch: 4[5280/5717 (92%)]	 Accuracy:25.000%	 Error:2.86
# Epoch: 4[5360/5717 (94%)]	 Accuracy:75.000%	 Error:1.32
# Epoch: 4[5440/5717 (95%)]	 Accuracy:75.000%	 Error:0.85
# Epoch: 4[5520/5717 (97%)]	 Accuracy:62.500%	 Error:1.40
# Epoch: 4[5600/5717 (98%)]	 Accuracy:87.500%	 Error:0.82
# Epoch: 4[5680/5717 (99%)]	 Accuracy:75.000%	 Error:0.99
# EPOCH:4, test_accuracy: 54.20560747663551
# 54.20560747663551>46.728971962616825
# Epoch: 5[0/5717 (0%)]	 Accuracy:37.500%	 Error:1.33
# Epoch: 5[80/5717 (1%)]	 Accuracy:50.000%	 Error:1.71
# Epoch: 5[160/5717 (3%)]	 Accuracy:62.500%	 Error:1.27
# Epoch: 5[240/5717 (4%)]	 Accuracy:50.000%	 Error:1.08
# Epoch: 5[320/5717 (6%)]	 Accuracy:62.500%	 Error:1.00
# Epoch: 5[400/5717 (7%)]	 Accuracy:75.000%	 Error:1.04
# Epoch: 5[480/5717 (8%)]	 Accuracy:87.500%	 Error:0.78
# Epoch: 5[560/5717 (10%)]	 Accuracy:37.500%	 Error:1.55
# Epoch: 5[640/5717 (11%)]	 Accuracy:50.000%	 Error:1.39
# Epoch: 5[720/5717 (13%)]	 Accuracy:62.500%	 Error:0.92
# Epoch: 5[800/5717 (14%)]	 Accuracy:75.000%	 Error:1.14
# Epoch: 5[880/5717 (15%)]	 Accuracy:50.000%	 Error:1.51
# Epoch: 5[960/5717 (17%)]	 Accuracy:75.000%	 Error:0.65
# Epoch: 5[1040/5717 (18%)]	 Accuracy:87.500%	 Error:0.80
# Epoch: 5[1120/5717 (20%)]	 Accuracy:25.000%	 Error:2.69
# Epoch: 5[1200/5717 (21%)]	 Accuracy:50.000%	 Error:1.26
# Epoch: 5[1280/5717 (22%)]	 Accuracy:75.000%	 Error:0.69
# Epoch: 5[1360/5717 (24%)]	 Accuracy:62.500%	 Error:0.91
# Epoch: 5[1440/5717 (25%)]	 Accuracy:75.000%	 Error:1.14
# Epoch: 5[1520/5717 (27%)]	 Accuracy:62.500%	 Error:1.41
# Epoch: 5[1600/5717 (28%)]	 Accuracy:75.000%	 Error:1.32
# Epoch: 5[1680/5717 (29%)]	 Accuracy:62.500%	 Error:1.30
# Epoch: 5[1760/5717 (31%)]	 Accuracy:37.500%	 Error:2.71
# Epoch: 5[1840/5717 (32%)]	 Accuracy:62.500%	 Error:1.45
# Epoch: 5[1920/5717 (34%)]	 Accuracy:62.500%	 Error:1.22
# Epoch: 5[2000/5717 (35%)]	 Accuracy:50.000%	 Error:1.44
# Epoch: 5[2080/5717 (36%)]	 Accuracy:50.000%	 Error:1.26
# Epoch: 5[2160/5717 (38%)]	 Accuracy:37.500%	 Error:1.86
# Epoch: 5[2240/5717 (39%)]	 Accuracy:62.500%	 Error:0.98
# Epoch: 5[2320/5717 (41%)]	 Accuracy:37.500%	 Error:1.37
# Epoch: 5[2400/5717 (42%)]	 Accuracy:62.500%	 Error:0.68
# Epoch: 5[2480/5717 (43%)]	 Accuracy:62.500%	 Error:1.04
# Epoch: 5[2560/5717 (45%)]	 Accuracy:62.500%	 Error:0.85
# Epoch: 5[2640/5717 (46%)]	 Accuracy:50.000%	 Error:1.92
# Epoch: 5[2720/5717 (48%)]	 Accuracy:75.000%	 Error:0.92
# Epoch: 5[2800/5717 (49%)]	 Accuracy:37.500%	 Error:1.56
# Epoch: 5[2880/5717 (50%)]	 Accuracy:37.500%	 Error:1.89
# Epoch: 5[2960/5717 (52%)]	 Accuracy:37.500%	 Error:1.82
# Epoch: 5[3040/5717 (53%)]	 Accuracy:62.500%	 Error:1.61
# Epoch: 5[3120/5717 (55%)]	 Accuracy:62.500%	 Error:1.34
# Epoch: 5[3200/5717 (56%)]	 Accuracy:87.500%	 Error:0.54
# Epoch: 5[3280/5717 (57%)]	 Accuracy:62.500%	 Error:1.25
# Epoch: 5[3360/5717 (59%)]	 Accuracy:50.000%	 Error:1.22
# Epoch: 5[3440/5717 (60%)]	 Accuracy:50.000%	 Error:1.77
# Epoch: 5[3520/5717 (62%)]	 Accuracy:87.500%	 Error:0.41
# Epoch: 5[3600/5717 (63%)]	 Accuracy:62.500%	 Error:1.12
# Epoch: 5[3680/5717 (64%)]	 Accuracy:100.000%	 Error:0.23
# Epoch: 5[3760/5717 (66%)]	 Accuracy:87.500%	 Error:0.54
# Epoch: 5[3840/5717 (67%)]	 Accuracy:50.000%	 Error:1.57
# Epoch: 5[3920/5717 (69%)]	 Accuracy:25.000%	 Error:2.43
# Epoch: 5[4000/5717 (70%)]	 Accuracy:87.500%	 Error:0.73
# Epoch: 5[4080/5717 (71%)]	 Accuracy:50.000%	 Error:1.39
# Epoch: 5[4160/5717 (73%)]	 Accuracy:75.000%	 Error:0.85
# Epoch: 5[4240/5717 (74%)]	 Accuracy:62.500%	 Error:1.01
# Epoch: 5[4320/5717 (76%)]	 Accuracy:37.500%	 Error:1.29
# Epoch: 5[4400/5717 (77%)]	 Accuracy:12.500%	 Error:2.21
# Epoch: 5[4480/5717 (78%)]	 Accuracy:25.000%	 Error:2.12
# Epoch: 5[4560/5717 (80%)]	 Accuracy:62.500%	 Error:1.53
# Epoch: 5[4640/5717 (81%)]	 Accuracy:62.500%	 Error:1.65
# Epoch: 5[4720/5717 (83%)]	 Accuracy:75.000%	 Error:1.19
# Epoch: 5[4800/5717 (84%)]	 Accuracy:50.000%	 Error:1.24
# Epoch: 5[4880/5717 (85%)]	 Accuracy:75.000%	 Error:0.81
# Epoch: 5[4960/5717 (87%)]	 Accuracy:75.000%	 Error:0.80
# Epoch: 5[5040/5717 (88%)]	 Accuracy:50.000%	 Error:1.20
# Epoch: 5[5120/5717 (90%)]	 Accuracy:37.500%	 Error:2.21
# Epoch: 5[5200/5717 (91%)]	 Accuracy:37.500%	 Error:1.42
# Epoch: 5[5280/5717 (92%)]	 Accuracy:50.000%	 Error:1.21
# Epoch: 5[5360/5717 (94%)]	 Accuracy:37.500%	 Error:1.73
# Epoch: 5[5440/5717 (95%)]	 Accuracy:50.000%	 Error:1.54
# Epoch: 5[5520/5717 (97%)]	 Accuracy:75.000%	 Error:1.21
# Epoch: 5[5600/5717 (98%)]	 Accuracy:62.500%	 Error:0.86
# Epoch: 5[5680/5717 (99%)]	 Accuracy:87.500%	 Error:0.42
# EPOCH:5, test_accuracy: 58.87850467289719
# Epoch: 6[0/5717 (0%)]	 Accuracy:37.500%	 Error:1.09
# Epoch: 6[80/5717 (1%)]	 Accuracy:37.500%	 Error:1.42
# Epoch: 6[160/5717 (3%)]	 Accuracy:62.500%	 Error:1.04
# Epoch: 6[240/5717 (4%)]	 Accuracy:37.500%	 Error:1.43
# Epoch: 6[320/5717 (6%)]	 Accuracy:87.500%	 Error:0.64
# Epoch: 6[400/5717 (7%)]	 Accuracy:75.000%	 Error:1.02
# Epoch: 6[480/5717 (8%)]	 Accuracy:62.500%	 Error:0.85
# Epoch: 6[560/5717 (10%)]	 Accuracy:75.000%	 Error:0.99
# Epoch: 6[640/5717 (11%)]	 Accuracy:62.500%	 Error:2.41
# Epoch: 6[720/5717 (13%)]	 Accuracy:62.500%	 Error:0.84
# Epoch: 6[800/5717 (14%)]	 Accuracy:50.000%	 Error:1.02
# Epoch: 6[880/5717 (15%)]	 Accuracy:62.500%	 Error:0.92
# Epoch: 6[960/5717 (17%)]	 Accuracy:75.000%	 Error:0.76
# Epoch: 6[1040/5717 (18%)]	 Accuracy:87.500%	 Error:0.52
# Epoch: 6[1120/5717 (20%)]	 Accuracy:37.500%	 Error:1.31
# Epoch: 6[1200/5717 (21%)]	 Accuracy:62.500%	 Error:1.14
# Epoch: 6[1280/5717 (22%)]	 Accuracy:100.000%	 Error:0.31
# Epoch: 6[1360/5717 (24%)]	 Accuracy:62.500%	 Error:1.07
# Epoch: 6[1440/5717 (25%)]	 Accuracy:87.500%	 Error:0.45
# Epoch: 6[1520/5717 (27%)]	 Accuracy:62.500%	 Error:1.63
# Epoch: 6[1600/5717 (28%)]	 Accuracy:37.500%	 Error:1.31
# Epoch: 6[1680/5717 (29%)]	 Accuracy:100.000%	 Error:0.17
# Epoch: 6[1760/5717 (31%)]	 Accuracy:62.500%	 Error:0.89
# Epoch: 6[1840/5717 (32%)]	 Accuracy:37.500%	 Error:1.82
# Epoch: 6[1920/5717 (34%)]	 Accuracy:25.000%	 Error:1.39
# Epoch: 6[2000/5717 (35%)]	 Accuracy:62.500%	 Error:1.09
# Epoch: 6[2080/5717 (36%)]	 Accuracy:62.500%	 Error:1.74
# Epoch: 6[2160/5717 (38%)]	 Accuracy:50.000%	 Error:2.00
# Epoch: 6[2240/5717 (39%)]	 Accuracy:50.000%	 Error:1.84
# Epoch: 6[2320/5717 (41%)]	 Accuracy:87.500%	 Error:0.55
# Epoch: 6[2400/5717 (42%)]	 Accuracy:75.000%	 Error:0.58
# Epoch: 6[2480/5717 (43%)]	 Accuracy:62.500%	 Error:1.01
# Epoch: 6[2560/5717 (45%)]	 Accuracy:37.500%	 Error:1.61
# Epoch: 6[2640/5717 (46%)]	 Accuracy:62.500%	 Error:1.00
# Epoch: 6[2720/5717 (48%)]	 Accuracy:62.500%	 Error:1.34
# Epoch: 6[2800/5717 (49%)]	 Accuracy:87.500%	 Error:0.82
# Epoch: 6[2880/5717 (50%)]	 Accuracy:87.500%	 Error:0.43
# Epoch: 6[2960/5717 (52%)]	 Accuracy:37.500%	 Error:2.32
# Epoch: 6[3040/5717 (53%)]	 Accuracy:62.500%	 Error:1.71
# Epoch: 6[3120/5717 (55%)]	 Accuracy:37.500%	 Error:1.17
# Epoch: 6[3200/5717 (56%)]	 Accuracy:50.000%	 Error:1.18
# Epoch: 6[3280/5717 (57%)]	 Accuracy:25.000%	 Error:1.60
# Epoch: 6[3360/5717 (59%)]	 Accuracy:50.000%	 Error:1.86
# Epoch: 6[3440/5717 (60%)]	 Accuracy:37.500%	 Error:1.14
# Epoch: 6[3520/5717 (62%)]	 Accuracy:62.500%	 Error:1.26
# Epoch: 6[3600/5717 (63%)]	 Accuracy:75.000%	 Error:0.73
# Epoch: 6[3680/5717 (64%)]	 Accuracy:75.000%	 Error:0.88
# Epoch: 6[3760/5717 (66%)]	 Accuracy:50.000%	 Error:1.15
# Epoch: 6[3840/5717 (67%)]	 Accuracy:62.500%	 Error:1.04
# Epoch: 6[3920/5717 (69%)]	 Accuracy:75.000%	 Error:0.89
# Epoch: 6[4000/5717 (70%)]	 Accuracy:62.500%	 Error:1.28
# Epoch: 6[4080/5717 (71%)]	 Accuracy:87.500%	 Error:0.40
# Epoch: 6[4160/5717 (73%)]	 Accuracy:87.500%	 Error:0.50
# Epoch: 6[4240/5717 (74%)]	 Accuracy:50.000%	 Error:1.44
# Epoch: 6[4320/5717 (76%)]	 Accuracy:50.000%	 Error:1.36
# Epoch: 6[4400/5717 (77%)]	 Accuracy:50.000%	 Error:1.20
# Epoch: 6[4480/5717 (78%)]	 Accuracy:50.000%	 Error:1.27
# Epoch: 6[4560/5717 (80%)]	 Accuracy:87.500%	 Error:0.53
# Epoch: 6[4640/5717 (81%)]	 Accuracy:75.000%	 Error:0.81
# Epoch: 6[4720/5717 (83%)]	 Accuracy:50.000%	 Error:1.17
# Epoch: 6[4800/5717 (84%)]	 Accuracy:50.000%	 Error:1.53
# Epoch: 6[4880/5717 (85%)]	 Accuracy:50.000%	 Error:1.26
# Epoch: 6[4960/5717 (87%)]	 Accuracy:50.000%	 Error:1.42
# Epoch: 6[5040/5717 (88%)]	 Accuracy:62.500%	 Error:1.33
# Epoch: 6[5120/5717 (90%)]	 Accuracy:62.500%	 Error:1.19
# Epoch: 6[5200/5717 (91%)]	 Accuracy:37.500%	 Error:1.80
# Epoch: 6[5280/5717 (92%)]	 Accuracy:50.000%	 Error:1.28
# Epoch: 6[5360/5717 (94%)]	 Accuracy:75.000%	 Error:0.78
# Epoch: 6[5440/5717 (95%)]	 Accuracy:50.000%	 Error:1.28
# Epoch: 6[5520/5717 (97%)]	 Accuracy:62.500%	 Error:0.90
# Epoch: 6[5600/5717 (98%)]	 Accuracy:75.000%	 Error:1.21
# Epoch: 6[5680/5717 (99%)]	 Accuracy:50.000%	 Error:1.39
# EPOCH:6, test_accuracy: 64.48598130841121
# 64.48598130841121>58.87850467289719
# Epoch: 7[0/5717 (0%)]	 Accuracy:62.500%	 Error:1.13
# Epoch: 7[80/5717 (1%)]	 Accuracy:50.000%	 Error:1.27
# Epoch: 7[160/5717 (3%)]	 Accuracy:75.000%	 Error:1.04
# Epoch: 7[240/5717 (4%)]	 Accuracy:50.000%	 Error:1.30
# Epoch: 7[320/5717 (6%)]	 Accuracy:75.000%	 Error:0.80
# Epoch: 7[400/5717 (7%)]	 Accuracy:50.000%	 Error:1.49
# Epoch: 7[480/5717 (8%)]	 Accuracy:50.000%	 Error:1.23
# Epoch: 7[560/5717 (10%)]	 Accuracy:37.500%	 Error:1.80
# Epoch: 7[640/5717 (11%)]	 Accuracy:62.500%	 Error:0.92
# Epoch: 7[720/5717 (13%)]	 Accuracy:50.000%	 Error:2.77
# Epoch: 7[800/5717 (14%)]	 Accuracy:75.000%	 Error:1.00
# Epoch: 7[880/5717 (15%)]	 Accuracy:62.500%	 Error:1.08
# Epoch: 7[960/5717 (17%)]	 Accuracy:50.000%	 Error:1.36
# Epoch: 7[1040/5717 (18%)]	 Accuracy:62.500%	 Error:1.05
# Epoch: 7[1120/5717 (20%)]	 Accuracy:50.000%	 Error:1.67
# Epoch: 7[1200/5717 (21%)]	 Accuracy:87.500%	 Error:0.48
# Epoch: 7[1280/5717 (22%)]	 Accuracy:87.500%	 Error:0.40
# Epoch: 7[1360/5717 (24%)]	 Accuracy:50.000%	 Error:1.63
# Epoch: 7[1440/5717 (25%)]	 Accuracy:62.500%	 Error:0.94
# Epoch: 7[1520/5717 (27%)]	 Accuracy:50.000%	 Error:1.36
# Epoch: 7[1600/5717 (28%)]	 Accuracy:100.000%	 Error:0.11
# Epoch: 7[1680/5717 (29%)]	 Accuracy:62.500%	 Error:0.96
# Epoch: 7[1760/5717 (31%)]	 Accuracy:75.000%	 Error:1.31
# Epoch: 7[1840/5717 (32%)]	 Accuracy:62.500%	 Error:0.88
# Epoch: 7[1920/5717 (34%)]	 Accuracy:50.000%	 Error:1.38
# Epoch: 7[2000/5717 (35%)]	 Accuracy:75.000%	 Error:0.70
# Epoch: 7[2080/5717 (36%)]	 Accuracy:62.500%	 Error:1.24
# Epoch: 7[2160/5717 (38%)]	 Accuracy:62.500%	 Error:0.95
# Epoch: 7[2240/5717 (39%)]	 Accuracy:37.500%	 Error:2.13
# Epoch: 7[2320/5717 (41%)]	 Accuracy:62.500%	 Error:1.07
# Epoch: 7[2400/5717 (42%)]	 Accuracy:75.000%	 Error:1.43
# Epoch: 7[2480/5717 (43%)]	 Accuracy:50.000%	 Error:1.40
# Epoch: 7[2560/5717 (45%)]	 Accuracy:37.500%	 Error:1.75
# Epoch: 7[2640/5717 (46%)]	 Accuracy:75.000%	 Error:1.08
# Epoch: 7[2720/5717 (48%)]	 Accuracy:37.500%	 Error:2.16
# Epoch: 7[2800/5717 (49%)]	 Accuracy:37.500%	 Error:1.61
# Epoch: 7[2880/5717 (50%)]	 Accuracy:50.000%	 Error:1.32
# Epoch: 7[2960/5717 (52%)]	 Accuracy:87.500%	 Error:0.45
# Epoch: 7[3040/5717 (53%)]	 Accuracy:62.500%	 Error:0.96
# Epoch: 7[3120/5717 (55%)]	 Accuracy:62.500%	 Error:0.97
# Epoch: 7[3200/5717 (56%)]	 Accuracy:75.000%	 Error:0.91
# Epoch: 7[3280/5717 (57%)]	 Accuracy:62.500%	 Error:0.72
# Epoch: 7[3360/5717 (59%)]	 Accuracy:50.000%	 Error:1.09
# Epoch: 7[3440/5717 (60%)]	 Accuracy:87.500%	 Error:0.63
# Epoch: 7[3520/5717 (62%)]	 Accuracy:75.000%	 Error:1.11
# Epoch: 7[3600/5717 (63%)]	 Accuracy:12.500%	 Error:2.41
# Epoch: 7[3680/5717 (64%)]	 Accuracy:62.500%	 Error:0.94
# Epoch: 7[3760/5717 (66%)]	 Accuracy:100.000%	 Error:0.29
# Epoch: 7[3840/5717 (67%)]	 Accuracy:75.000%	 Error:1.05
# Epoch: 7[3920/5717 (69%)]	 Accuracy:100.000%	 Error:0.08
# Epoch: 7[4000/5717 (70%)]	 Accuracy:75.000%	 Error:0.99
# Epoch: 7[4080/5717 (71%)]	 Accuracy:87.500%	 Error:2.03
# Epoch: 7[4160/5717 (73%)]	 Accuracy:62.500%	 Error:1.39
# Epoch: 7[4240/5717 (74%)]	 Accuracy:37.500%	 Error:1.51
# Epoch: 7[4320/5717 (76%)]	 Accuracy:87.500%	 Error:0.57
# Epoch: 7[4400/5717 (77%)]	 Accuracy:50.000%	 Error:1.00
# Epoch: 7[4480/5717 (78%)]	 Accuracy:25.000%	 Error:1.93
# Epoch: 7[4560/5717 (80%)]	 Accuracy:62.500%	 Error:1.11
# Epoch: 7[4640/5717 (81%)]	 Accuracy:87.500%	 Error:0.68
# Epoch: 7[4720/5717 (83%)]	 Accuracy:62.500%	 Error:1.64
# Epoch: 7[4800/5717 (84%)]	 Accuracy:75.000%	 Error:0.90
# Epoch: 7[4880/5717 (85%)]	 Accuracy:50.000%	 Error:1.33
# Epoch: 7[4960/5717 (87%)]	 Accuracy:75.000%	 Error:0.77
# Epoch: 7[5040/5717 (88%)]	 Accuracy:25.000%	 Error:1.65
# Epoch: 7[5120/5717 (90%)]	 Accuracy:62.500%	 Error:1.36
# Epoch: 7[5200/5717 (91%)]	 Accuracy:87.500%	 Error:0.66
# Epoch: 7[5280/5717 (92%)]	 Accuracy:37.500%	 Error:2.46
# Epoch: 7[5360/5717 (94%)]	 Accuracy:62.500%	 Error:1.10
# Epoch: 7[5440/5717 (95%)]	 Accuracy:87.500%	 Error:0.68
# Epoch: 7[5520/5717 (97%)]	 Accuracy:62.500%	 Error:0.95
# Epoch: 7[5600/5717 (98%)]	 Accuracy:62.500%	 Error:0.78
# Epoch: 7[5680/5717 (99%)]	 Accuracy:75.000%	 Error:0.70
# EPOCH:7, test_accuracy: 53.271028037383175
# Epoch: 8[0/5717 (0%)]	 Accuracy:50.000%	 Error:1.03
# Epoch: 8[80/5717 (1%)]	 Accuracy:87.500%	 Error:0.40
# Epoch: 8[160/5717 (3%)]	 Accuracy:37.500%	 Error:1.26
# Epoch: 8[240/5717 (4%)]	 Accuracy:75.000%	 Error:1.39
# Epoch: 8[320/5717 (6%)]	 Accuracy:62.500%	 Error:0.96
# Epoch: 8[400/5717 (7%)]	 Accuracy:62.500%	 Error:1.34
# Epoch: 8[480/5717 (8%)]	 Accuracy:75.000%	 Error:0.74
# Epoch: 8[560/5717 (10%)]	 Accuracy:50.000%	 Error:0.98
# Epoch: 8[640/5717 (11%)]	 Accuracy:37.500%	 Error:1.69
# Epoch: 8[720/5717 (13%)]	 Accuracy:37.500%	 Error:1.77
# Epoch: 8[800/5717 (14%)]	 Accuracy:25.000%	 Error:2.50
# Epoch: 8[880/5717 (15%)]	 Accuracy:75.000%	 Error:0.42
# Epoch: 8[960/5717 (17%)]	 Accuracy:75.000%	 Error:0.89
# Epoch: 8[1040/5717 (18%)]	 Accuracy:62.500%	 Error:0.93
# Epoch: 8[1120/5717 (20%)]	 Accuracy:87.500%	 Error:0.76
# Epoch: 8[1200/5717 (21%)]	 Accuracy:62.500%	 Error:0.88
# Epoch: 8[1280/5717 (22%)]	 Accuracy:62.500%	 Error:1.20
# Epoch: 8[1360/5717 (24%)]	 Accuracy:62.500%	 Error:1.64
# Epoch: 8[1440/5717 (25%)]	 Accuracy:75.000%	 Error:0.59
# Epoch: 8[1520/5717 (27%)]	 Accuracy:37.500%	 Error:1.39
# Epoch: 8[1600/5717 (28%)]	 Accuracy:75.000%	 Error:0.75
# Epoch: 8[1680/5717 (29%)]	 Accuracy:75.000%	 Error:0.57
# Epoch: 8[1760/5717 (31%)]	 Accuracy:37.500%	 Error:1.48
# Epoch: 8[1840/5717 (32%)]	 Accuracy:37.500%	 Error:1.41
# Epoch: 8[1920/5717 (34%)]	 Accuracy:62.500%	 Error:0.96
# Epoch: 8[2000/5717 (35%)]	 Accuracy:75.000%	 Error:0.45
# Epoch: 8[2080/5717 (36%)]	 Accuracy:37.500%	 Error:2.61
# Epoch: 8[2160/5717 (38%)]	 Accuracy:62.500%	 Error:0.98
# Epoch: 8[2240/5717 (39%)]	 Accuracy:87.500%	 Error:0.89
# Epoch: 8[2320/5717 (41%)]	 Accuracy:75.000%	 Error:0.86
# Epoch: 8[2400/5717 (42%)]	 Accuracy:75.000%	 Error:0.54
# Epoch: 8[2480/5717 (43%)]	 Accuracy:75.000%	 Error:0.73
# Epoch: 8[2560/5717 (45%)]	 Accuracy:37.500%	 Error:1.57
# Epoch: 8[2640/5717 (46%)]	 Accuracy:75.000%	 Error:0.76
# Epoch: 8[2720/5717 (48%)]	 Accuracy:62.500%	 Error:0.74
# Epoch: 8[2800/5717 (49%)]	 Accuracy:62.500%	 Error:1.05
# Epoch: 8[2880/5717 (50%)]	 Accuracy:50.000%	 Error:1.06
# Epoch: 8[2960/5717 (52%)]	 Accuracy:62.500%	 Error:0.99
# Epoch: 8[3040/5717 (53%)]	 Accuracy:75.000%	 Error:0.73
# Epoch: 8[3120/5717 (55%)]	 Accuracy:75.000%	 Error:0.82
# Epoch: 8[3200/5717 (56%)]	 Accuracy:62.500%	 Error:1.08
# Epoch: 8[3280/5717 (57%)]	 Accuracy:50.000%	 Error:1.15
# Epoch: 8[3360/5717 (59%)]	 Accuracy:62.500%	 Error:0.86
# Epoch: 8[3440/5717 (60%)]	 Accuracy:87.500%	 Error:0.28
# Epoch: 8[3520/5717 (62%)]	 Accuracy:75.000%	 Error:0.64
# Epoch: 8[3600/5717 (63%)]	 Accuracy:75.000%	 Error:0.62
# Epoch: 8[3680/5717 (64%)]	 Accuracy:100.000%	 Error:0.28
# Epoch: 8[3760/5717 (66%)]	 Accuracy:62.500%	 Error:0.84
# Epoch: 8[3840/5717 (67%)]	 Accuracy:75.000%	 Error:1.78
# Epoch: 8[3920/5717 (69%)]	 Accuracy:50.000%	 Error:1.01
# Epoch: 8[4000/5717 (70%)]	 Accuracy:75.000%	 Error:0.94
# Epoch: 8[4080/5717 (71%)]	 Accuracy:75.000%	 Error:1.07
# Epoch: 8[4160/5717 (73%)]	 Accuracy:37.500%	 Error:1.97
# Epoch: 8[4240/5717 (74%)]	 Accuracy:62.500%	 Error:1.44
# Epoch: 8[4320/5717 (76%)]	 Accuracy:50.000%	 Error:1.15
# Epoch: 8[4400/5717 (77%)]	 Accuracy:37.500%	 Error:1.32
# Epoch: 8[4480/5717 (78%)]	 Accuracy:62.500%	 Error:1.51
# Epoch: 8[4560/5717 (80%)]	 Accuracy:62.500%	 Error:0.88
# Epoch: 8[4640/5717 (81%)]	 Accuracy:37.500%	 Error:1.50
# Epoch: 8[4720/5717 (83%)]	 Accuracy:87.500%	 Error:0.58
# Epoch: 8[4800/5717 (84%)]	 Accuracy:75.000%	 Error:0.77
# Epoch: 8[4880/5717 (85%)]	 Accuracy:62.500%	 Error:1.29
# Epoch: 8[4960/5717 (87%)]	 Accuracy:75.000%	 Error:0.84
# Epoch: 8[5040/5717 (88%)]	 Accuracy:75.000%	 Error:0.78
# Epoch: 8[5120/5717 (90%)]	 Accuracy:37.500%	 Error:1.50
# Epoch: 8[5200/5717 (91%)]	 Accuracy:62.500%	 Error:1.20
# Epoch: 8[5280/5717 (92%)]	 Accuracy:87.500%	 Error:0.97
# Epoch: 8[5360/5717 (94%)]	 Accuracy:62.500%	 Error:0.99
# Epoch: 8[5440/5717 (95%)]	 Accuracy:75.000%	 Error:0.74
# Epoch: 8[5520/5717 (97%)]	 Accuracy:75.000%	 Error:0.68
# Epoch: 8[5600/5717 (98%)]	 Accuracy:50.000%	 Error:1.22
# Epoch: 8[5680/5717 (99%)]	 Accuracy:75.000%	 Error:0.78
# EPOCH:8, test_accuracy: 58.87850467289719
# 58.87850467289719>55.140186915887845
# Epoch: 9[0/5717 (0%)]	 Accuracy:50.000%	 Error:1.72
# Epoch: 9[80/5717 (1%)]	 Accuracy:87.500%	 Error:0.29
# Epoch: 9[160/5717 (3%)]	 Accuracy:62.500%	 Error:1.02
# Epoch: 9[240/5717 (4%)]	 Accuracy:75.000%	 Error:0.33
# Epoch: 9[320/5717 (6%)]	 Accuracy:37.500%	 Error:1.19
# Epoch: 9[400/5717 (7%)]	 Accuracy:62.500%	 Error:0.79
# Epoch: 9[480/5717 (8%)]	 Accuracy:50.000%	 Error:1.18
# Epoch: 9[560/5717 (10%)]	 Accuracy:62.500%	 Error:1.09
# Epoch: 9[640/5717 (11%)]	 Accuracy:50.000%	 Error:1.37
# Epoch: 9[720/5717 (13%)]	 Accuracy:62.500%	 Error:0.87
# Epoch: 9[800/5717 (14%)]	 Accuracy:100.000%	 Error:0.65
# Epoch: 9[880/5717 (15%)]	 Accuracy:62.500%	 Error:0.92
# Epoch: 9[960/5717 (17%)]	 Accuracy:50.000%	 Error:1.53
# Epoch: 9[1040/5717 (18%)]	 Accuracy:62.500%	 Error:1.04
# Epoch: 9[1120/5717 (20%)]	 Accuracy:50.000%	 Error:1.39
# Epoch: 9[1200/5717 (21%)]	 Accuracy:62.500%	 Error:1.47
# Epoch: 9[1280/5717 (22%)]	 Accuracy:87.500%	 Error:0.64
# Epoch: 9[1360/5717 (24%)]	 Accuracy:75.000%	 Error:1.62
# Epoch: 9[1440/5717 (25%)]	 Accuracy:50.000%	 Error:1.27
# Epoch: 9[1520/5717 (27%)]	 Accuracy:25.000%	 Error:1.46
# Epoch: 9[1600/5717 (28%)]	 Accuracy:50.000%	 Error:1.84
# Epoch: 9[1680/5717 (29%)]	 Accuracy:62.500%	 Error:0.72
# Epoch: 9[1760/5717 (31%)]	 Accuracy:87.500%	 Error:0.42
# Epoch: 9[1840/5717 (32%)]	 Accuracy:75.000%	 Error:1.06
# Epoch: 9[1920/5717 (34%)]	 Accuracy:62.500%	 Error:1.46
# Epoch: 9[2000/5717 (35%)]	 Accuracy:50.000%	 Error:1.36
# Epoch: 9[2080/5717 (36%)]	 Accuracy:62.500%	 Error:1.59
# Epoch: 9[2160/5717 (38%)]	 Accuracy:87.500%	 Error:0.57

# %%
predictions = []
gts = []
train_X = []
for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
    var_X_batch = Variable(X_batch).to(device=device)
    var_y_batch = Variable(y_batch).to(device=device)

    output = lane_net(var_X_batch)
    predicted = torch.max(output.data, 1)[1] 

    predictions.append(predicted.cpu().detach().numpy()[0])
    gts.append(var_y_batch.cpu().detach().numpy()[0])
    total_train_accuracy = (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 

print( "Training Accuracy: ", (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 )

# %%
predictions = []
gts = []
train_X = []
for batch_idx, (X_batch, y_batch) in enumerate(test_loader):
    var_X_batch = Variable(X_batch).float().to(device=device)
    var_y_batch = Variable(y_batch).to(device=device)

    output = lane_net(var_X_batch)
    predicted = torch.max(output.data, 1)[1] 

    predictions.append(predicted.cpu().detach().numpy()[0])
    gts.append(var_y_batch.cpu().detach().numpy()[0])
    total_train_accuracy = (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 

print( "Test Accuracy: ", (np.array(predictions) == np.array(gts)).sum() / len(predictions) * 100 )

# %%
# PATH = 'dense_lane.pt'
# torch.save(lane_net.state_dict(), PATH)

# %%
print(total_train_accuracy)
